# %%
import pandas as pd 
import numpy as np
from helpers import *
import coach_dicts
import os

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# Validation libraries
from sklearn import metrics
from sklearn.metrics import accuracy_score, recall_score, balanced_accuracy_score, precision_score, precision_recall_curve
from sklearn.metrics import confusion_matrix, plot_confusion_matrix
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold, cross_val_score

# Display plots inside the notebook
# %matplotlib inline

# Ignore warning related to pandas_profiling
import warnings
warnings.filterwarnings('ignore') 

from pathlib import Path

# Display all dataframe columns in outputs (it has 63 columns, which is wider than the notebook)
# This sets it up to display with a horizontal scroll instead of hiding the middle columns
pd.set_option('display.max_columns', 800) 
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_rows', 1800)

# %%
path = os.environ.get("DATA_PATH")

# %%
data = "intervention_only_leona_2.csv"

# %%
df = pd.read_csv(path + data, sep= ";", low_memory = False)

# %%
df.replace (' ', np.nan, inplace=True)

# %%
column_list = df.columns.tolist()

# %%
column_list
# Out:
# ['accessCodeId',
#  'mtkId',
#  'codeEntered',
#  'registration',
#  'studyInfo',
#  'studyVariant',
#  'coach',
#  'problem',
#  'dropout',
#  'M1_measurementPos',
#  'M2_measurementPos',
#  'M3_measurementPos',
#  'M4_measurementPos',
#  'M5_measurementPos',
#  'M6_measurementPos',
#  'M7_measurementPos',
#  'TI_score',
#  'TI_bip1',
#  'TI_bip2',
#  'TI_hyp_x',
#  'TI_MDE',
#  'TI_dyst',
#  'TI_MDE_x',
#  'TI_20_xx',
#  'TI_F20_8',
#  'TI_F25',
#  'TI_F22',
#  'TI_F23',
#  'TI_F29',
#  'TI_MDE_vr',
#  'TI_MDE_tr',
#  'TI_HYP_vr',
#  'TI_MAN_vr',
#  'TI_medik',
#  'TI_inkl',
#  'TI_rekrut',
#  'in_ther1',
#  'in_ther2',
#  'in_med1',
#  'in_med2',
#  '1_module',
#  '2_module',
#  '3_module',
#  '4_module',
#  '5_module',
#  '6_module',
#  '7_module',
#  'POST_screening_start',
#  'FU1_screening_start',
#  'FU2_screening_start',
#  'FU3_screening_start',
#  '1_login',
#  '2_login',
#  '3_login',
#  '4_login',
#  '5_login',
#  '6_login',
#  '7_login',
#  '1_login_duration',
#  '2_login_duration',
#  '3_login_duration',
#  '4_login_duration',
#  '5_login_duration',
#  '6_login_duration',
#  '7_login_duration',
#  '1_feedback',
#  'M1_feedback',
#  'M2_feedback',
#  'M3_feedback',
#  'M4_feedback',
#  'M5_feedback',
#  'M6_feedback',
#  '1_fb_duration',
#  '2_fb_duration',
#  '3_fb_duration',
#  '4_fb_duration',
#  '5_fb_duration',
#  '6_fb_duration',
#  '7_fb_duration',
#  '1_fb_size',
#  '2_fb_size',
#  '3_fb_size',
#  '4_fb_size',
#  '5_fb_size',
#  '6_fb_size',
#  '7_fb_size',
#  '1_reminder',
#  '2_reminder',
#  '3_reminder',
#  '4_reminder',
#  '5_reminder',
#  '6_reminder',
#  '7_reminder',
#  '1_contact_unplanned',
#  '2_contact_unplanned',
#  '3_contact_unplanned',
#  '4_contact_unplanned',
#  '5_contact_unplanned',
#  '6_contact_unplanned',
#  '7_contact_unplanned',
#  '1_letter',
#  '2_letter',
#  '7_letter',
#  '1_letter_size',
#  '2_letter_size',
#  '7_letter_size',
#  'M3_planner_quantity',
#  'M4_planner_quantity',
#  'M5_planner_quantity',
#  'M6_planner_quantity',
#  'M7_planner_quantity',
#  'M3_diary_quantity',
#  'M4_diary_quantity',
#  'M5_diary_quantity',
#  'M6_diary_quantity',
#  'M7_diary_quantity',
#  'M3_positive_quantity',
#  'M4_positive_quantity',
#  'M5_positive_quantity',
#  'M6_positive_quantity',
#  'M7_positive_quantity',
#  'M5_1_nbt_duration',
#  'M5_2_nbt_duration',
#  'M5_3_nbt_duration',
#  'M6_1_nbt_duration',
#  'M6_2_nbt_duration',
#  'M6_3_nbt_duration',
#  'M5_1_nbt_duration_nobreaks',
#  'M5_2_nbt_duration_nobreaks',
#  'M5_3_nbt_duration_nobreaks',
#  'M6_1_nbt_duration_nobreaks',
#  'M6_2_nbt_duration_nobreaks',
#  'M6_3_nbt_duration_nobreaks',
#  'M5_1_nbt_breaks_count',
#  'M5_2_nbt_breaks_count',
#  'M5_3_nbt_breaks_count',
#  'M6_1_nbt_breaks_count',
#  'M6_2_nbt_breaks_count',
#  'M6_3_nbt_breaks_count',
#  'M5_1_1_nbt_answer',
#  'M5_1_2_nbt_answer',
#  'M5_1_3_nbt_answer',
#  'M5_1_4_nbt_answer',
#  'M5_1_5_nbt_answer',
#  'M5_1_6_nbt_answer',
#  'M5_1_7_nbt_answer',
#  'M5_1_8_nbt_answer',
#  'M5_1_9_nbt_answer',
#  'M5_1_10_nbt_answer',
#  'M5_2_1_nbt_answer',
#  'M5_2_2_nbt_answer',
#  'M5_2_3_nbt_answer',
#  'M5_2_4_nbt_answer',
#  'M5_2_5_nbt_answer',
#  'M5_2_6_nbt_answer',
#  'M5_2_7_nbt_answer',
#  'M5_2_8_nbt_answer',
#  'M5_2_9_nbt_answer',
#  'M5_2_10_nbt_answer',
#  'M5_3_1_nbt_answer',
#  'M5_3_2_nbt_answer',
#  'M5_3_3_nbt_answer',
#  'M5_3_4_nbt_answer',
#  'M5_3_5_nbt_answer',
#  'M5_3_6_nbt_answer',
#  'M5_3_7_nbt_answer',
#  'M5_3_8_nbt_answer',
#  'M5_3_9_nbt_answer',
#  'M5_3_10_nbt_answer',
#  'M6_1_1_nbt_answer',
#  'M6_1_2_nbt_answer',
#  'M6_1_3_nbt_answer',
#  'M6_1_4_nbt_answer',
#  'M6_1_5_nbt_answer',
#  'M6_2_1_nbt_answer',
#  'M6_2_2_nbt_answer',
#  'M6_2_3_nbt_answer',
#  'M6_2_4_nbt_answer',
#  'M6_2_5_nbt_answer',
#  'M6_3_1_nbt_answer',
#  'M6_3_2_nbt_answer',
#  'M6_3_3_nbt_answer',
#  'M6_3_4_nbt_answer',
#  'M6_3_5_nbt_answer',
#  'M6_protocol_quantity',
#  'M7_protocol_quantity',
#  'PRE_birth',
#  'PRE_sex',
#  'PRE_education',
#  'PRE_work',
#  'PRE_household',
#  'PRE_relation',
#  'PRE_residence',
#  'PRE_internet',
#  'PRE_height',
#  'PRE_weight',
#  'PRE_treatment',
#  'PRE_ambul1',
#  'PRE_ambul2',
#  'PRE_ambul3',
#  'PRE_ambul4',
#  'PRE_ambul5',
#  'PRE_ambul6',
#  'PRE_tagesk1',
#  'PRE_tagesk2',
#  'PRE_tagesk3',
#  'PRE_tagesk4',
#  'PRE_tagesk5',
#  'PRE_tagesk6',
#  'PRE_psychiat1',
#  'PRE_psychiat2',
#  'PRE_psychiat3',
#  'PRE_psychiat4',
#  'PRE_psychiat5',
#  'PRE_psychiat6',
#  'PRE_abspr1',
#  'PRE_abspr2',
#  'PRE_abspr3',
#  'PRE_PT_planned',
#  'PRE_support',
#  'PRE_kPT',
#  'PRE_material',
#  'PRE_material_comments',
#  'PRE_ill',
#  'PRE_ill_comments',
#  'PRE_sickleave',
#  'PRE_sickleave_comments',
#  'PRE_doc',
#  'PRE_doc_comments',
#  'PRE_neurol',
#  'PRE_neurol_comments',
#  'PRE_selfhelp',
#  'PRE_selfhelp_comments',
#  'PRE_counsel',
#  'PRE_counsel_comments',
#  'PRE_therapy',
#  'PRE_therapy_comments',
#  'PRE_med',
#  'PRE_hospital',
#  'PRE_hospital_comments',
#  'PRE_hos_other',
#  'PRE_hos_other_comments',
#  'PRE_bdi1',
#  'PRE_bdi2',
#  'PRE_bdi3',
#  'PRE_bdi4',
#  'PRE_bdi5',
#  'PRE_bdi6',
#  'PRE_bdi7',
#  'PRE_bdi8',
#  'PRE_bdi9',
#  'PRE_bdi10',
#  'PRE_bdi11',
#  'PRE_bdi12',
#  'PRE_bdi13',
#  'PRE_bdi14',
#  'PRE_bdi15',
#  'PRE_bdi16',
#  'PRE_bdi17',
#  'PRE_bdi18',
#  'PRE_bdi19',
#  'PRE_bdi20',
#  'PRE_bdi21',
#  'PRE_phqS1',
#  'PRE_phqS2',
#  'PRE_phqS3',
#  'PRE_phqS4',
#  'PRE_phqS5',
#  'PRE_phqS6',
#  'PRE_phqS7',
#  'PRE_phqS8',
#  'PRE_phqS9',
#  'PRE_phqS10',
#  'PRE_phqD1',
#  'PRE_phqD2',
#  'PRE_phqD3',
#  'PRE_phqD4',
#  'PRE_phqD5',
#  'PRE_phqD6',
#  'PRE_phqD7',
#  'PRE_phqD8',
#  'PRE_phqD9',
#  'PRE_gad1',
#  'PRE_gad2',
#  'PRE_gad3',
#  'PRE_gad4',
#  'PRE_gad5',
#  'PRE_gad6',
#  'PRE_gad7',
#  'PRE_phqZ',
#  'PRE_costa1',
#  'PRE_costa2',
#  'PRE_costa3',
#  'PRE_costa4',
#  'PRE_costa5',
#  'PRE_costa6',
#  'PRE_costa7',
#  'PRE_costa8',
#  'PRE_costa9',
#  'PRE_costa10',
#  'PRE_costa11',
#  'PRE_costa12',
#  'PRE_costa13',
#  'PRE_costa14',
#  'PRE_costa15',
#  'PRE_costa16',
#  'PRE_costa17',
#  'PRE_costa18',
#  'PRE_costa19',
#  'PRE_costa20',
#  'PRE_costa21',
#  'PRE_pathev1',
#  'PRE_pathev2',
#  'PRE_pathev3',
#  'PRE_pathev4',
#  'PRE_pathev5',
#  'PRE_pathev6',
#  'PRE_pathev7',
#  'PRE_pathev8',
#  'PRE_pathev9',
#  'PRE_pathev10',
#  'PRE_euheals1',
#  'PRE_euheals2',
#  'PRE_euheals3',
#  'PRE_ipqr1',
#  'PRE_ipqr2',
#  'PRE_ipqr3',
#  'PRE_ipqr4',
#  'PRE_ipqr5',
#  'PRE_ipqr6',
#  'PRE_ipqr7',
#  'PRE_ipqr8',
#  'PRE_ipqr9',
#  'PRE_ipqr10',
#  'PRE_ipqr11',
#  'PRE_ipqr12',
#  'PRE_ipqr13',
#  'PRE_ipqr14',
#  'PRE_ipqr15',
#  'PRE_ipqr16',
#  'PRE_ipqr17',
#  'PRE_ipqr18',
#  'PRE_eurohis1',
#  'PRE_eurohis2',
#  'PRE_eurohis3',
#  'PRE_eurohis4',
#  'PRE_eurohis5',
#  'PRE_eurohis6',
#  'PRE_eurohis7',
#  'PRE_eurohis8',
#  'PRE_imet1',
#  'PRE_imet2',
#  'PRE_imet3',
#  'PRE_imet4',
#  'PRE_imet5',
#  'PRE_imet6',
#  'PRE_imet7',
#  'PRE_imet8',
#  'PRE_imet9',
#  'PRE_imet10',
#  'PRE_bsss1',
#  'PRE_bsss2',
#  'PRE_bsss3',
#  'PRE_bsss4',
#  'PRE_bsss5',
#  'PRE_bsss6',
#  'PRE_bsss7',
#  'PRE_bsss8',
#  'PRE_bsss9',
#  'PRE_bsss10',
#  'PRE_bsss11',
#  'PRE_bsss12',
#  'PRE_bsss13',
#  'PRE_gpse1',
#  'PRE_gpse2',
#  'PRE_gpse3',
#  'PRE_gpse4',
#  'PRE_gpse5',
#  'PRE_gpse6',
#  'PRE_gpse7',
#  'PRE_gpse8',
#  'PRE_gpse9',
#  'PRE_gpse10',
#  'PRE_pvq1',
#  'PRE_pvq2',
#  'PRE_pvq3',
#  'PRE_pvq4',
#  'PRE_pvq5',
#  'PRE_pvq6',
#  'PRE_pvq7',
#  'PRE_pvq8',
#  'PRE_pvq9',
#  'PRE_pvq10',
#  'PRE_pvq11',
#  'PRE_pvq12',
#  'PRE_pvq13',
#  'PRE_pvq14',
#  'PRE_pvq15',
#  'PRE_pvq16',
#  'PRE_pvq17',
#  'PRE_pvq18',
#  'PRE_pvq19',
#  'PRE_pvq20',
#  'PRE_pvq21',
#  'M1_phqD1',
#  'M1_phqD2',
#  'M1_phqD3',
#  'M1_phqD4',
#  'M1_phqD5',
#  'M1_phqD6',
#  'M1_phqD7',
#  'M1_phqD8',
#  'M1_phqD9',
#  'M1_planer_duration',
#  'M1_diary_duration',
#  'M1_protocol_duration',
#  'M1_letter_duration',
#  'M3_phqD1',
#  'M3_phqD2',
#  'M3_phqD3',
#  'M3_phqD4',
#  'M3_phqD5',
#  'M3_phqD6',
#  'M3_phqD7',
#  'M3_phqD8',
#  'M3_phqD9',
#  'M3_costa1',
#  'M3_costa2',
#  'M3_costa3',
#  'M3_costa4',
#  'M3_costa5',
#  'M3_costa6',
#  'M3_costa7',
#  'M3_costa8',
#  'M3_costa9',
#  'M3_costa10',
#  'M3_costa11',
#  'M3_costa12',
#  'M3_costa13',
#  'M3_costa14',
#  'M3_costa15',
#  'M3_costa16',
#  'M3_costa17',
#  'M3_costa18',
#  'M3_costa19',
#  'M3_costa20',
#  'M3_costa21',
#  'M3_sewip1',
#  'M3_sewip2',
#  'M3_sewip3',
#  'M3_sewip4',
#  'M3_sewip5',
#  'M3_sewip6',
#  'M3_sewip7',
#  'M3_sewip8',
#  'M3_sewip9',
#  'M3_sewip10',
#  'M3_sewip11',
#  'M3_sewip12',
#  'M3_sewip13',
#  'M3_sewip14',
#  'M3_sewip15',
#  'M3_sewip16',
#  'M3_sewip17',
#  'M3_sewip18',
#  'M3_sewip19',
#  'M3_sewip20',
#  'M3_sewip21',
#  'M3_planer_duration',
#  'M3_diary_duration',
#  'M3_protocol_duration',
#  'M3_letter_duration',
#  'M4_phqD1',
#  'M4_phqD2',
#  'M4_phqD3',
#  'M4_phqD4',
#  'M4_phqD5',
#  'M4_phqD6',
#  'M4_phqD7',
#  'M4_phqD8',
#  'M4_phqD9',
#  'M4_planer_duration',
#  'M4_diary_duration',
#  'M4_protocol_duration',
#  'M4_letter_duration',
#  'M5_phqD1',
#  'M5_phqD2',
#  'M5_phqD3',
#  'M5_phqD4',
#  'M5_phqD5',
#  'M5_phqD6',
#  'M5_phqD7',
#  'M5_phqD8',
#  'M5_phqD9',
#  'M5_costa1',
#  'M5_costa2',
#  'M5_costa3',
#  'M5_costa4',
#  'M5_costa5',
#  'M5_costa6',
#  'M5_costa7',
#  'M5_costa8',
#  'M5_costa9',
#  'M5_costa10',
#  'M5_costa11',
#  'M5_costa12',
#  'M5_costa13',
#  'M5_costa14',
#  'M5_costa15',
#  'M5_costa16',
#  'M5_costa17',
#  'M5_costa18',
#  'M5_costa19',
#  'M5_costa20',
#  'M5_costa21',
#  'M5_sewip1',
#  'M5_sewip2',
#  'M5_sewip3',
#  'M5_sewip4',
#  'M5_sewip5',
#  'M5_sewip6',
#  'M5_sewip7',
#  'M5_sewip8',
#  'M5_sewip9',
#  'M5_sewip10',
#  'M5_sewip11',
#  'M5_sewip12',
#  'M5_sewip13',
#  'M5_sewip14',
#  'M5_sewip15',
#  'M5_sewip16',
#  'M5_sewip17',
#  'M5_sewip18',
#  'M5_sewip19',
#  'M5_sewip20',
#  'M5_sewip21',
#  'M5_planer_duration',
#  'M5_diary_duration',
#  'M5_protocol_duration',
#  'M5_letter_duration',
#  'M6_phqD1',
#  'M6_phqD2',
#  'M6_phqD3',
#  'M6_phqD4',
#  'M6_phqD5',
#  'M6_phqD6',
#  'M6_phqD7',
#  'M6_phqD8',
#  'M6_phqD9',
#  'M6_planer_duration',
#  'M6_diary_duration',
#  'M6_protocol_duration',
#  'M6_letter_duration',
#  'M7_phqD1',
#  'M7_phqD2',
#  'M7_phqD3',
#  'M7_phqD4',
#  'M7_phqD5',
#  'M7_phqD6',
#  'M7_phqD7',
#  'M7_phqD8',
#  'M7_phqD9',
#  'M7_planer_duration',
#  'M7_diary_duration',
#  'M7_protocol_duration',
#  'M7_letter_duration',
#  'M7_2_planer_duration',
#  'M7_2_diary_duration',
#  'M7_2_protocol_duration',
#  'M7_2_letter_duration',
#  'POST_material',
#  'POST_material_comments',
#  'POST_ill',
#  'POST_ill_comments',
#  'POST_sickleave',
#  'POST_sickleave_comments',
#  'POST_doc',
#  'POST_doc_comments',
#  'POST_neurol',
#  'POST_neurol_comments',
#  'POST_selfhelp',
#  'POST_selfhelp_comments',
#  'POST_counsel',
#  'POST_counsel_comments',
#  'POST_therapy',
#  'POST_therapy_comments',
#  'POST_med',
#  'POST_hospital',
#  'POST_hospital_comments',
#  'POST_hos_other',
#  'POST_hos_other_comments',
#  'POST_bdi1',
#  'POST_bdi2',
#  'POST_bdi3',
#  'POST_bdi4',
#  'POST_bdi5',
#  'POST_bdi6',
#  'POST_bdi7',
#  'POST_bdi8',
#  'POST_bdi9',
#  'POST_bdi10',
#  'POST_bdi11',
#  'POST_bdi12',
#  'POST_bdi13',
#  'POST_bdi14',
#  'POST_bdi15',
#  'POST_bdi16',
#  'POST_bdi17',
#  'POST_bdi18',
#  'POST_bdi19',
#  'POST_bdi20',
#  'POST_bdi21',
#  'POST_phqS1',
#  'POST_phqS2',
#  'POST_phqS3',
#  'POST_phqS4',
#  'POST_phqS5',
#  'POST_phqS6',
#  'POST_phqS7',
#  'POST_phqS8',
#  'POST_phqS9',
#  'POST_phqS10',
#  'POST_phqD1',
#  'POST_phqD2',
#  'POST_phqD3',
#  'POST_phqD4',
#  'POST_phqD5',
#  'POST_phqD6',
#  'POST_phqD7',
#  'POST_phqD8',
#  'POST_phqD9',
#  'POST_gad1',
#  'POST_gad2',
#  'POST_gad3',
#  'POST_gad4',
#  'POST_gad5',
#  'POST_gad6',
#  'POST_gad7',
#  'POST_phqZ',
#  'POST_costa1',
#  'POST_costa2',
#  'POST_costa3',
#  'POST_costa4',
#  'POST_costa5',
#  'POST_costa6',
#  'POST_costa7',
#  'POST_costa8',
#  'POST_costa9',
#  'POST_costa10',
#  'POST_costa11',
#  'POST_costa12',
#  'POST_costa13',
#  'POST_costa14',
#  'POST_costa15',
#  'POST_costa16',
#  'POST_costa17',
#  'POST_costa18',
#  'POST_costa19',
#  'POST_costa20',
#  'POST_costa21',
#  'POST_eurohis1',
#  'POST_eurohis2',
#  'POST_eurohis3',
#  'POST_eurohis4',
#  'POST_eurohis5',
#  'POST_eurohis6',
#  'POST_eurohis7',
#  'POST_eurohis8',
#  'POST_imet1',
#  'POST_imet2',
#  'POST_imet3',
#  'POST_imet4',
#  'POST_imet5',
#  'POST_imet6',
#  'POST_imet7',
#  'POST_imet8',
#  'POST_imet9',
#  'POST_imet10',
#  'POST_bsss1',
#  'POST_bsss2',
#  'POST_bsss3',
#  'POST_bsss4',
#  'POST_bsss5',
#  'POST_bsss6',
#  'POST_bsss7',
#  'POST_bsss8',
#  'POST_bsss9',
#  'POST_bsss10',
#  'POST_bsss11',
#  'POST_bsss12',
#  'POST_bsss13',
#  'POST_gpse1',
#  'POST_gpse2',
#  'POST_gpse3',
#  'POST_gpse4',
#  'POST_gpse5',
#  'POST_gpse6',
#  'POST_gpse7',
#  'POST_gpse8',
#  'POST_gpse9',
#  'POST_gpse10',
#  'POST_sides1',
#  'V716_1',
#  'V716_2',
#  'POST_tk_satisfied',
#  'POST_tk_phase1',
#  'POST_tk_phase2',
#  'POST_tk_phase3',
#  'POST_tk_phase4',
#  'POST_tk_phase5',
#  'POST_tk_phase6',
#  'POST_tk_phase7',
#  'POST_tk_phase8',
#  'POST_tk_duration',
#  'POST_tk_comprehend',
#  'POST_tk_recommend',
#  'POST_tk_helpful',
#  'POST_tk_comparison',
#  'POST_tk_navigation',
#  'POST_tk_support1',
#  'POST_tk_support2',
#  'POST_tk_support3',
#  'POST_tk_support4',
#  'POST_tk_support5',
#  'POST_tk_support6',
#  'POST_tk_support_med1',
#  'POST_tk_support_med2',
#  'POST_tk_support_med3',
#  'POST_tk_support_med4',
#  'POST_tk_support_med5',
#  'POST_tk_support_med6',
#  'POST_tk_support_comments',
#  'V744_1',
#  'V744_2',
#  'POST_kPT',
#  'POST_kPT_comment',
#  'V746_1',
#  'V746_2',
#  'POST_tk_comment',
#  'V747_1',
#  'V747_2',
#  'V747_3',
#  'V747_4',
#  'POST_sewip1',
#  'POST_sewip2',
#  'POST_sewip3',
#  'POST_sewip4',
#  'POST_sewip5',
#  'POST_sewip6',
#  'POST_sewip7',
#  'POST_sewip8',
#  'POST_sewip9',
#  'POST_sewip10',
#  'POST_sewip11',
#  'POST_sewip12',
#  'POST_sewip13',
#  'POST_sewip14',
#  'POST_sewip15',
#  'POST_sewip16',
#  'POST_sewip17',
#  'POST_sewip18',
#  'POST_sewip19',
#  'POST_sewip20',
#  'POST_sewip21']

# %% [markdown]
# ### Create shortened df

# %% [markdown]
# The following predictors were chosen for the current analysis:
#
# - df2 = BDI/PHQ (Post), PHQ M1, Pre: SKID-Diagnosen, IMET, EUROHIS_QUOL, BDI, PHQ-D, PHQ-S, GAD, Soziodemographisch, Costa, GPSE, BSSS, PATHEV + EUHEALS, IPQ-R, PVQ, SEWiP, Nutzung d. Gesundheitswesens
# - additional = 2_letter, 2_letter_size, 2_fb_size, 2_reminder, 2_module, 1_letter, 1_letter_size

# %%
column_zwei = ['registration','studyVariant','coach','PRE_bdi1','PRE_bdi2',
               'PRE_bdi3','PRE_bdi4','PRE_bdi5','PRE_bdi6','PRE_bdi7','PRE_bdi8','PRE_bdi9','PRE_bdi10',
               'PRE_bdi11','PRE_bdi12','PRE_bdi13','PRE_bdi14','PRE_bdi15','PRE_bdi16','PRE_bdi17','PRE_bdi18',
               'PRE_bdi19','PRE_bdi20','PRE_bdi21','POST_phqD1','POST_phqD2','POST_phqD3','POST_phqD4','POST_phqD5',
               'POST_phqD6','POST_phqD7','POST_phqD8','POST_phqD9',
               'PRE_phqS1','PRE_phqS2','PRE_phqS3','PRE_phqS4','PRE_phqS5','PRE_phqS6','PRE_phqS7',
               'PRE_phqS8','PRE_phqS9','PRE_phqS10','PRE_phqD1','PRE_phqD2','PRE_phqD3','PRE_phqD4','PRE_phqD5',
               'PRE_phqD6','PRE_phqD7','PRE_phqD8','PRE_phqD9', 'PRE_birth','PRE_sex','PRE_education',
               'PRE_work','PRE_household','PRE_relation','PRE_residence','PRE_internet','PRE_height','PRE_weight',
               'PRE_treatment','PRE_support','PRE_kPT','PRE_ill','PRE_sickleave','PRE_doc',
               'PRE_neurol','PRE_selfhelp','PRE_counsel','PRE_therapy','PRE_med','PRE_hospital',
               'PRE_hos_other', 'PRE_eurohis1','PRE_eurohis2','PRE_eurohis3','PRE_eurohis4','PRE_eurohis5',
               'PRE_eurohis6','PRE_eurohis7','PRE_eurohis8', 'TI_score','TI_bip1',
               'TI_bip2','TI_hyp_x','TI_MDE','TI_dyst','TI_MDE_x','TI_20_xx','TI_F20_8','TI_F25','TI_F22','TI_F23',
               'TI_F29','TI_MDE_vr','TI_MDE_tr','TI_HYP_vr','TI_MAN_vr','TI_medik','TI_rekrut','PRE_gad1',
               'PRE_gad2','PRE_gad3','PRE_gad4','PRE_gad5','PRE_gad6','PRE_gad7', 'PRE_costa1', 'PRE_costa2', 'PRE_costa3',
              'PRE_costa4', 'PRE_costa5', 'PRE_costa6', 'PRE_costa7', 'PRE_costa8', 'PRE_costa9', 'PRE_costa10', 'PRE_costa11',
              'PRE_costa12', 'PRE_costa13', 'PRE_costa14', 'PRE_costa15', 'PRE_costa16', 'PRE_costa17', 'PRE_costa18',
              'PRE_costa19', 'PRE_costa20', 'PRE_costa21', 'PRE_pathev1', 'PRE_pathev2', 'PRE_pathev3', 'PRE_pathev4',
              'PRE_pathev5', 'PRE_pathev6', 'PRE_pathev7', 'PRE_pathev8', 'PRE_pathev9', 'PRE_pathev10', 
              'PRE_euheals1','PRE_euheals2','PRE_euheals3','PRE_ipqr1','PRE_ipqr2','PRE_ipqr3','PRE_ipqr4','PRE_ipqr5',
               'PRE_ipqr6','PRE_ipqr7','PRE_ipqr8','PRE_ipqr9','PRE_ipqr10','PRE_ipqr11','PRE_ipqr12','PRE_ipqr13',
               'PRE_ipqr14','PRE_ipqr15','PRE_ipqr16','PRE_ipqr17','PRE_ipqr18', 'PRE_bsss1','PRE_bsss2','PRE_bsss3',
               'PRE_bsss4','PRE_bsss5','PRE_bsss6','PRE_bsss7','PRE_bsss8','PRE_bsss9','PRE_bsss10','PRE_bsss11',
               'PRE_bsss12','PRE_bsss13','PRE_gpse1','PRE_gpse2','PRE_gpse3','PRE_gpse4','PRE_gpse5','PRE_gpse6',
               'PRE_gpse7','PRE_gpse8','PRE_gpse9','PRE_gpse10','PRE_pvq1','PRE_pvq2','PRE_pvq3','PRE_pvq4','PRE_pvq5',
               'PRE_pvq6','PRE_pvq7','PRE_pvq8','PRE_pvq9','PRE_pvq10','PRE_pvq11','PRE_pvq12','PRE_pvq13','PRE_pvq14',
               'PRE_pvq15','PRE_pvq16','PRE_pvq17','PRE_pvq18','PRE_pvq19','PRE_pvq20','PRE_pvq21', 'PRE_imet1','PRE_imet2','PRE_imet3','PRE_imet4','PRE_imet5','PRE_imet6','PRE_imet7',
                'PRE_imet8','PRE_imet9','PRE_imet10']

# %% [markdown]
# To Do:
# * df["dropout"] umändern in binäre Variablen
# * Study Variant in binäre Variable
# * Birth Year in Age umwandeln
# * Hight und Weight in BDI umwandeln
# * Anzahl Diagnosen zählen
# * Therapist Variablen anonymisieren und Alter, Geschlecht, Abschluss extrahieren
# * Skalen auswerten: IPQr8 umpolen, IMET10 umpolen
# * Dummy Categorize TI_rekrut, PRE_work, PRE_household, PRE_residence
# * Standardize TI_Score, BMI, Age, Internet (optional; not necessary for RF; erst nach Train-Test_Split)
# * Transform Post_BDI to RCI
# * Idea: Handle registration date as cyclical feature
# * Idea: Fancier strategies for missing values
#
# Notizen:
# * PRE_pt_planned raus, da PatientInnen ausgeschlossen werden, die eine PT geplant haben

# %%
df2 = df[column_zwei]

# %% [markdown]
# # 1. Prepare first dataframe for first analysis

# %% [markdown]
# ## 1.1 Check out Missing Values

# %% [markdown]
# ### 1.1.1 Drop rows with missing values on outcome

# %%
miss_df2 = missing_values_table(df2)
miss_df2
# Out:
# The dataset has 215 columns.
# There are 118 columns that have missing values.
#              Missing Values  % of Total Values  \
# POST_phqD1    499            28.1
# POST_phqD3    499            28.1
# POST_phqD4    499            28.1
# POST_phqD5    499            28.1
# POST_phqD6    499            28.1
# POST_phqD7    499            28.1
# POST_phqD8    499            28.1
# POST_phqD9    499            28.1
# POST_phqD2    499            28.1
# PRE_phqS4     19             1.1
# PRE_pathev2   18             1.0
# PRE_imet9     16             0.9
# PRE_euheals3  13             0.7
# PRE_phqS6     13             0.7
# PRE_imet8     13             0.7
# PRE_gpse8     10             0.6
# PRE_pathev8   10             0.6
# PRE_phqS5     10             0.6
# PRE_pathev10  9              0.5
# PRE_gpse9     8              0.5
# PRE_phqS3     8              0.5
# PRE_pathev6   7              0.4
# PRE_gpse6     6              0.3
# PRE_imet7     6              0.3
# PRE_pathev7   6              0.3
# PRE_gpse7     5              0.3
# PRE_gpse10    5              0.3
# PRE_euheals2  5              0.3
# PRE_euheals1  5              0.3
# PRE_pvq3      5              0.3
# PRE_pathev9   5              0.3
# PRE_pvq17     5              0.3
# PRE_imet10    5              0.3
# PRE_pvq2      4              0.2
# PRE_pvq1      4              0.2
# PRE_pvq4      4              0.2
# PRE_pvq14     4              0.2
# PRE_gpse4     4              0.2
# PRE_imet2     4              0.2
# PRE_costa21   4              0.2
# PRE_ipqr2     3              0.2
# PRE_eurohis6  3              0.2
# PRE_pvq5      3              0.2
# PRE_pvq6      3              0.2
# PRE_pvq7      3              0.2
# PRE_pathev5   3              0.2
# PRE_pvq18     3              0.2
# PRE_pvq19     3              0.2
# PRE_gpse2     3              0.2
# PRE_pvq21     3              0.2
# PRE_costa18   3              0.2
# PRE_costa17   3              0.2
# PRE_imet3     3              0.2
# PRE_imet4     3              0.2
# PRE_imet5     3              0.2
# PRE_imet6     3              0.2
# PRE_ipqr17    3              0.2
# PRE_costa11   3              0.2
# PRE_gpse1     2              0.1
# PRE_gpse3     2              0.1
# PRE_gpse5     2              0.1
# PRE_eurohis5  2              0.1
# PRE_costa9    2              0.1
# PRE_pvq16     2              0.1
# PRE_phqS10    2              0.1
# PRE_pvq11     2              0.1
# PRE_bsss3     2              0.1
# PRE_phqS9     2              0.1
# PRE_pvq20     2              0.1
# PRE_imet1     2              0.1
# PRE_phqS7     2              0.1
# PRE_costa10   2              0.1
# PRE_ipqr1     2              0.1
# PRE_costa20   2              0.1
# PRE_costa19   2              0.1
# PRE_costa4    2              0.1
# PRE_costa2    2              0.1
# PRE_costa5    2              0.1
# PRE_costa6    2              0.1
# PRE_pathev4   2              0.1
# PRE_ipqr3     2              0.1
# PRE_costa7    2              0.1
# PRE_pathev1   2              0.1
# PRE_costa3    2              0.1
# PRE_ipqr9     2              0.1
# PRE_ipqr12    2              0.1
# PRE_costa13   2              0.1
# PRE_costa16   1              0.1
# PRE_pvq12     1              0.1
# PRE_costa15   1              0.1
# PRE_pathev3   1              0.1
# PRE_costa14   1              0.1
# PRE_phqS8     1              0.1
# PRE_costa12   1              0.1
# PRE_pvq15     1              0.1
# PRE_phqS1     1              0.1
# PRE_pvq13     1              0.1
# PRE_bsss2     1              0.1
# PRE_pvq9      1              0.1
# PRE_pvq10     1              0.1
# PRE_eurohis3  1              0.1
# PRE_bsss1     1              0.1
# PRE_bsss8     1              0.1
# PRE_ipqr14    1              0.1
# PRE_ipqr13    1              0.1
# PRE_ipqr11    1              0.1
# PRE_ipqr8     1              0.1
# PRE_eurohis4  1              0.1
# PRE_eurohis2  1              0.1
# PRE_bsss4     1              0.1
# PRE_eurohis1  1              0.1
# PRE_ipqr7     1              0.1
# PRE_ipqr5     1              0.1
# PRE_eurohis7  1              0.1
# PRE_eurohis8  1              0.1
# PRE_costa1    1              0.1
# PRE_pvq8      1              0.1
# PRE_bsss7     1              0.1
#
#                                        Missing Values
# POST_phqD1    [nan, 2, 0, 1, 3]
# POST_phqD3    [nan, 1, 0, 2, 3]
# POST_phqD4    [nan, 2, 1, 3, 0]
# POST_phqD5    [nan, 1, 2, 0, 3]
# POST_phqD6    [nan, 2, 0, 1, 3]
# POST_phqD7    [nan, 1, 0, 2, 3]
# POST_phqD8    [nan, 0, 1, 2, 3]
# POST_phqD9    [nan, 1, 0, 2]
# POST_phqD2    [nan, 2, 0, 1, 3]
# PRE_phqS4     [2, 1, 0, nan]
# PRE_pathev2   [1, 2, 5, 4, 3, nan]
# PRE_imet9     [7, 10, 8, 5, 2, 4, 9, 3, 0, 1, 6, nan]
# PRE_euheals3  [9, 5, 1, nan]
# PRE_phqS6     [1, 2, 0, nan]
# PRE_imet8     [7, 10, 5, 3, 0, 8, 9, 2, 4, 1, 6, nan]
# PRE_gpse8     [2, 1, 3, 4, nan]
# PRE_pathev8   [4, 1, 3, 5, 2, nan]
# PRE_phqS5     [1, 0, 2, nan]
# PRE_pathev10  [2, 1, 3, 4, nan, 5]
# PRE_gpse9     [2, 1, 3, 4, nan]
# PRE_phqS3     [1, 2, 0, nan]
# PRE_pathev6   [4, 2, 3, 5, 1, nan]
# PRE_gpse6     [2, 1, 3, 4, nan]
# PRE_imet7     [6, 2, 7, 5, 3, 10, 1, 0, 9, 4, 8, nan]
# PRE_pathev7   [1, 4, 2, 3, 5, nan]
# PRE_gpse7     [2, 3, 4, 1, nan]
# PRE_gpse10    [2, 3, 4, nan, 1]
# PRE_euheals2  [9, 5, 1, nan]
# PRE_euheals1  [9, 5, nan, 1]
# PRE_pvq3      [2, 3, 1, 4, 5, 6, nan]
# PRE_pathev9   [1, 3, 2, 4, 5, nan]
# PRE_pvq17     [3, 2, 5, 4, 6, 1, nan]
# PRE_imet10    [8, 10, 7, 5, 9, 4, 2, 6, 0, 3, nan, 1]
# PRE_pvq2      [3, 4, 5, 6, 2, 1, nan]
# PRE_pvq1      [2, 3, 1, 6, 5, 4, nan]
# PRE_pvq4      [3, 2, 1, 5, 4, 6, nan]
# PRE_pvq14     [2, 1, 3, 5, 4, 6, nan]
# PRE_gpse4     [2, 3, 1, 4, nan]
# PRE_imet2     [3, 0, 7, 4, 1, 6, 5, 2, 9, 8, 10, nan]
# PRE_costa21   [4, 3, 2, 0, 1, 5, nan]
# PRE_ipqr2     [4, 3, 5, 2, nan, 1]
# PRE_eurohis6  [2, 4, 3, 5, 1, nan]
# PRE_pvq5      [5, 2, 1, 3, 4, 6, nan]
# PRE_pvq6      [2, 5, 3, 4, 6, 1, nan]
# PRE_pvq7      [2, 5, 3, 4, 6, 1, nan]
# PRE_pathev5   [1, 3, 2, 4, 5, nan]
# PRE_pvq18     [2, 1, 3, nan, 4, 5]
# PRE_pvq19     [2, 3, 1, 5, 4, 6, nan]
# PRE_gpse2     [3, 2, 4, 1, nan]
# PRE_pvq21     [3, 4, 2, 5, 6, nan, 1]
# PRE_costa18   [4, 3, 2, 0, 1, nan, 5]
# PRE_costa17   [3, 4, 0, 5, 1, 2, nan]
# PRE_imet3     [2, 4, 6, 3, 0, 1, 8, 9, 7, 5, 10, nan]
# PRE_imet4     [2, 8, 3, 5, 4, 1, 0, 7, 6, 9, 10, nan]
# PRE_imet5     [2, 5, 6, 8, 9, 7, 3, 1, 4, 10, 0, nan]
# PRE_imet6     [6, 5, 4, 2, 3, 10, 8, 7, 9, 1, 0, nan]
# PRE_ipqr17    [4, 3, 5, 2, 1, nan]
# PRE_costa11   [4, 1, 2, 3, 5, 0, nan]
# PRE_gpse1     [2, 1, 3, 4, nan]
# PRE_gpse3     [2, 1, 3, 4, nan]
# PRE_gpse5     [2, 3, 1, 4, nan]
# PRE_eurohis5  [2, 4, 5, 1, 3, nan]
# PRE_costa9    [5, 3, 2, 0, 4, 1, nan]
# PRE_pvq16     [2, 1, 3, 5, 4, 6, nan]
# PRE_phqS10    [2, 0, 1, nan]
# PRE_pvq11     [1, 3, 2, 5, 4, 6, nan]
# PRE_bsss3     [2, 3, 4, 1, nan]
# PRE_phqS9     [1, 0, 2, nan]
# PRE_pvq20     [5, 4, 6, 3, 1, 2, nan]
# PRE_imet1     [2, 0, 7, 3, 1, 6, 5, 9, 8, 4, 10, nan]
# PRE_phqS7     [2, 0, 1, nan]
# PRE_costa10   [3, 2, 4, 0, 1, nan, 5]
# PRE_ipqr1     [4, 5, 2, 3, 1, nan]
# PRE_costa20   [3, 1, 5, 0, 2, 4, nan]
# PRE_costa19   [4, 2, 5, 0, 3, 1, nan]
# PRE_costa4    [4, 2, 5, 3, 1, 0, nan]
# PRE_costa2    [4, 3, 5, 2, 0, 1, nan]
# PRE_costa5    [4, 2, 5, 3, 0, 1, nan]
# PRE_costa6    [4, 3, 2, 1, 0, nan, 5]
# PRE_pathev4   [2, 5, 3, 4, 1, nan]
# PRE_ipqr3     [4, 3, 2, 5, 1, nan]
# PRE_costa7    [4, 1, 3, 0, 2, nan, 5]
# PRE_pathev1   [1, 2, 3, 4, 5, nan]
# PRE_costa3    [4, 1, 3, 5, 0, 2, nan]
# PRE_ipqr9     [4, 2, 1, 3, 5, nan]
# PRE_ipqr12    [2, 4, 3, 1, 5, nan]
# PRE_costa13   [3, 2, 4, 0, 1, nan, 5]
# PRE_costa16   [4, 3, 2, 1, nan, 5, 0]
# PRE_pvq12     [2, 3, 1, 4, 5, 6, nan]
# PRE_costa15   [4, 3, 2, 0, 5, 1, nan]
# PRE_pathev3   [1, 4, 2, 3, 5, nan]
# PRE_costa14   [4, 3, 5, 0, 2, 1, nan]
# PRE_phqS8     [2, 0, 1, nan]
# PRE_costa12   [4, 2, 5, 3, 1, nan, 0]
# PRE_pvq15     [3, 5, 4, 6, 1, 2, nan]
# PRE_phqS1     [1, 0, 2, nan]
# PRE_pvq13     [2, 1, 3, 4, 5, 6, nan]
# PRE_bsss2     [3, 2, 4, 1, nan]
# PRE_pvq9      [4, 2, 3, 5, 6, 1, nan]
# PRE_pvq10     [2, 4, 3, 1, 5, 6, nan]
# PRE_eurohis3  [2, 1, 4, 3, 5, nan]
# PRE_bsss1     [3, 4, 2, 1, nan]
# PRE_bsss8     [2, 3, 4, 1, nan]
# PRE_ipqr14    [4, 2, 3, 1, nan, 5]
# PRE_ipqr13    [4, 1, 5, 3, 2, nan]
# PRE_ipqr11    [2, 3, 1, 4, 5, nan]
# PRE_ipqr8     [4, 3, 5, 2, nan, 1]
# PRE_eurohis4  [2, 1, 4, 3, 5, nan]
# PRE_eurohis2  [2, 1, 3, 4, 5, nan]
# PRE_bsss4     [2, 3, 1, 4, nan]
# PRE_eurohis1  [2, 4, 3, 5, 1, nan]
# PRE_ipqr7     [2, 3, 1, 4, 5, nan]
# PRE_ipqr5     [4, 2, 3, 5, 1, nan]
# PRE_eurohis7  [3, 4, 2, 5, 1, nan]
# PRE_eurohis8  [2, 4, 1, 5, 3, nan]
# PRE_costa1    [4, 1, 3, 0, 2, 5, nan]
# PRE_pvq8      [2, 3, 1, 5, 4, 6, nan]
# PRE_bsss7     [2, 3, 4, 1, nan]

# %%
post_phq_columns = ['POST_phqD1','POST_phqD2','POST_phqD3','POST_phqD4','POST_phqD5',
               'POST_phqD6','POST_phqD7','POST_phqD8','POST_phqD9']

# %%
df2 = df2[df2[post_phq_columns].notnull().all(axis=1)]

# %% [markdown]
# ### 1.1.2 Drop columns referring to exclusion criteria
#
# Diagnosen:
# * F20.8: Schizophrenie = Exclusion criterion --> Drop
# * F29: Nicht näher bezeichnete nichtorganische Psychose = Exclusion criterion --> Drop
# * F23: Akute vorübergehende psychotische Störungen = Exclusion criterion --> Drop
# * F22: Wahnhafte Störung = Exclusion criterion --> Drop
# * F25: Schizoaffektive Störung = Exclusion criterion --> Drop
# * F20: Paranoide Schizophrenie = Exclusion criterion --> Drop
# * TI_hyp_x: Hypomania --> Drop

# %%
exclusion_cols = ["TI_F20_8", "TI_F29", "TI_F23", "TI_F22", "TI_hyp_x", "TI_F25", "TI_20_xx"]

# %%
df2.drop(exclusion_cols, axis=1, inplace=True)

# %% [markdown]
# ### 1.1.3 Replace missing categorical values with mode

# %% [markdown]
# Some data types are object --> we will turn them numeric to allow replacement with mode value

# %%
miss_df2 = missing_values_table(df2)
missing_cols = miss_df2.index.tolist()
# Out:
# The dataset has 208 columns.
# There are 105 columns that have missing values.

# %%
df_test = df2[missing_cols]

# %%
for column in missing_cols:
    df2[column] = pd.to_numeric(df2[column], errors='coerce').astype('Int64')

# %%
def fillna_with_mode(df, column):
    mode = df[column].mode()[0]

    df[column] = df[column].fillna(mode)

# %%
for column in missing_cols:
    fillna_with_mode(df2, column)

# %%
miss_df2 = missing_values_table(df2)
miss_df2
# Out:
# The dataset has 208 columns.
# There are 0 columns that have missing values.
# Empty DataFrame
# Columns: [Missing Values, % of Total Values, Missing Values]
# Index: []

# %% [markdown]
# ## 1.2 Aggregate and Transform columns

# %% [markdown]
# ### 1.2.1 Turn study variant into a binary variable

# %%
df2['studyVariant'] = pd.get_dummies(df2['studyVariant'])

# %% [markdown]
# ### 1.2.2 Create extra columns with number of diagnoses

# %%
diagnose_columns = ['TI_bip1','TI_bip2','TI_MDE','TI_dyst','TI_MDE_x','TI_MDE_vr','TI_MDE_tr','TI_HYP_vr',
                    'TI_MAN_vr','TI_medik']

# %%
df2["n_diagn"] = df2[diagnose_columns].sum(axis=1)

# %% [markdown]
# ### 1.2.3 Anonymize coach variable and extract gender

# %%
coach_dict = coach_dicts.coach_dict

# %%
anonym_dict = coach_dicts.anonym_dict

# %%
df2["coach_gender"] = df2["coach"]
df2.replace({"coach_gender": coach_dict}, inplace=True)

# %%
df2.replace({"coach": anonym_dict}, inplace=True)

# %%
df2["coach"] = df2["coach"].astype("|S")

# %% [markdown]
# ### 1.2.4 Check dtypes and answer formats

# %%
answer_table = show_answers(df2)
answer_table
# Out:
#                Amount of Answers                 Anwers
# Item
# registration   594                Free Input
# PRE_weight     91                 Free Input
# PRE_birth      66                 Free Input
# PRE_internet   55                 Free Input
# PRE_height     53                 Free Input
# TI_score       21                 Free Input
# coach          20                 Free Input
# PRE_imet8      11                 Free Input
# PRE_imet10     11                 Free Input
# PRE_imet6      11                 Free Input
# PRE_imet5      11                 Free Input
# PRE_imet4      11                 Free Input
# PRE_imet3      11                 Free Input
# PRE_imet2      11                 Free Input
# PRE_imet9      11                 Free Input
# TI_rekrut      11                 Free Input
# PRE_imet7      11                 Free Input
# PRE_imet1      10                 Free Input
# PRE_work       7                  [2, 5, 6, 1, 7, 3, 4]
# PRE_costa15    6                  [3, 2, 0, 4, 1, 5]
# PRE_costa16    6                  [3, 2, 4, 1, 5, 0]
# PRE_costa14    6                  [3, 5, 0, 2, 4, 1]
# PRE_costa13    6                  [2, 0, 1, 3, 4, 5]
# PRE_costa10    6                  [2, 0, 3, 1, 5, 4]
# PRE_costa12    6                  [2, 3, 4, 1, 5, 0]
# PRE_costa11    6                  [1, 3, 5, 4, 2, 0]
# PRE_costa3     6                  [1, 3, 5, 0, 4, 2]
# PRE_costa9     6                  [3, 2, 0, 1, 4, 5]
# PRE_costa8     6                  [2, 3, 0, 1, 4, 5]
# PRE_costa7     6                  [1, 3, 0, 4, 2, 5]
# PRE_costa6     6                  [3, 2, 1, 4, 0, 5]
# PRE_costa5     6                  [2, 3, 0, 4, 5, 1]
# PRE_costa18    6                  [3, 2, 0, 4, 5, 1]
# PRE_costa2     6                  [3, 2, 0, 5, 4, 1]
# PRE_costa1     6                  [1, 4, 3, 0, 2, 5]
# PRE_costa17    6                  [3, 0, 5, 4, 1, 2]
# PRE_pvq1       6                  [3, 1, 6, 2, 5, 4]
# PRE_costa19    6                  [2, 0, 3, 1, 4, 5]
# PRE_costa20    6                  [1, 3, 0, 2, 4, 5]
# PRE_pvq21      6                  [4, 2, 5, 6, 3, 1]
# PRE_pvq20      6                  [4, 5, 6, 3, 1, 2]
# PRE_pvq19      6                  [3, 2, 1, 4, 5, 6]
# PRE_pvq17      6                  [3, 2, 5, 4, 6, 1]
# PRE_pvq16      6                  [2, 3, 5, 4, 1, 6]
# PRE_pvq15      6                  [5, 3, 6, 4, 1, 2]
# PRE_pvq14      6                  [2, 3, 5, 6, 4, 1]
# PRE_pvq13      6                  [2, 3, 4, 1, 5, 6]
# PRE_pvq12      6                  [2, 3, 1, 4, 5, 6]
# PRE_pvq11      6                  [3, 1, 2, 5, 4, 6]
# PRE_pvq10      6                  [4, 2, 1, 5, 3, 6]
# PRE_pvq9       6                  [2, 3, 5, 4, 6, 1]
# PRE_pvq8       6                  [3, 2, 1, 5, 4, 6]
# PRE_pvq7       6                  [2, 3, 4, 5, 6, 1]
# PRE_pvq6       6                  [5, 3, 4, 2, 6, 1]
# PRE_pvq5       6                  [2, 1, 3, 4, 5, 6]
# PRE_pvq3       6                  [3, 1, 2, 4, 5, 6]
# PRE_pvq2       6                  [4, 6, 3, 5, 2, 1]
# PRE_costa21    6                  [3, 2, 0, 1, 5, 4]
# PRE_pvq4       6                  [2, 1, 3, 5, 4, 6]
# PRE_costa4     6                  [2, 4, 3, 1, 0, 5]
# PRE_education  6                  [3, 5, 4, 2, 1, 0]
# PRE_residence  5                  [3, 4, 2, 1, 5]
# PRE_ipqr18     5                  [4, 3, 5, 2, 1]
# PRE_ipqr15     5                  [1, 5, 4, 2, 3]
# PRE_ipqr14     5                  [2, 4, 1, 3, 5]
# PRE_ipqr13     5                  [1, 4, 5, 3, 2]
# PRE_ipqr12     5                  [4, 3, 1, 5, 2]
# PRE_ipqr11     5                  [2, 3, 1, 4, 5]
# PRE_ipqr10     5                  [2, 5, 1, 3, 4]
# PRE_ipqr9      5                  [2, 1, 3, 4, 5]
# PRE_ipqr8      5                  [4, 5, 3, 2, 1]
# PRE_ipqr7      5                  [2, 1, 4, 3, 5]
# PRE_ipqr6      5                  [4, 5, 3, 1, 2]
# PRE_ipqr5      5                  [4, 3, 2, 5, 1]
# PRE_ipqr3      5                  [3, 4, 2, 5, 1]
# PRE_ipqr2      5                  [4, 3, 5, 2, 1]
# PRE_ipqr1      5                  [4, 5, 2, 3, 1]
# PRE_pathev10   5                  [1, 3, 2, 4, 5]
# PRE_pathev9    5                  [3, 1, 2, 4, 5]
# PRE_pathev8    5                  [1, 5, 2, 3, 4]
# PRE_pathev7    5                  [4, 1, 2, 3, 5]
# PRE_pathev6    5                  [2, 5, 4, 3, 1]
# PRE_pathev5    5                  [3, 1, 2, 4, 5]
# PRE_pathev4    5                  [2, 5, 3, 4, 1]
# PRE_pathev3    5                  [4, 1, 2, 3, 5]
# PRE_pathev2    5                  [2, 5, 4, 1, 3]
# PRE_pathev1    5                  [2, 1, 3, 4, 5]
# PRE_ipqr17     5                  [4, 3, 5, 2, 1]
# PRE_ipqr16     5                  [3, 4, 5, 2, 1]
# PRE_eurohis4   5                  [2, 4, 3, 1, 5]
# n_diagn        5                  [1, 2, 0, 3, 4]
# PRE_pvq18      5                  [2, 1, 3, 4, 5]
# PRE_household  5                  [2, 4, 1, 0, 3]
# PRE_eurohis8   5                  [4, 5, 2, 3, 1]
# PRE_eurohis7   5                  [4, 3, 2, 5, 1]
# PRE_eurohis6   5                  [4, 3, 5, 2, 1]
# PRE_eurohis5   5                  [4, 5, 2, 1, 3]
# PRE_eurohis3   5                  [2, 4, 1, 3, 5]
# PRE_eurohis2   5                  [2, 3, 1, 4, 5]
# PRE_eurohis1   5                  [4, 3, 2, 5, 1]
# PRE_bsss12     4                  [3, 4, 2, 1]
# PRE_bsss9      4                  [3, 2, 4, 1]
# PRE_bsss10     4                  [2, 1, 3, 4]
# PRE_bsss11     4                  [2, 3, 4, 1]
# PRE_bsss1      4                  [3, 4, 2, 1]
# PRE_bsss13     4                  [3, 2, 1, 4]
# PRE_gpse1      4                  [2, 3, 4, 1]
# PRE_bsss7      4                  [3, 2, 4, 1]
# PRE_gpse2      4                  [3, 4, 2, 1]
# PRE_bsss8      4                  [3, 2, 4, 1]
# PRE_bsss5      4                  [3, 4, 2, 1]
# PRE_gpse6      4                  [2, 3, 1, 4]
# PRE_gpse5      4                  [2, 3, 1, 4]
# PRE_relation   4                  [1, 0, 2, 3]
# PRE_bsss6      4                  [3, 2, 4, 1]
# PRE_gpse8      4                  [2, 3, 4, 1]
# PRE_bsss4      4                  [3, 4, 1, 2]
# PRE_ipqr4      4                  [4, 5, 3, 2]
# PRE_bsss3      4                  [3, 2, 4, 1]
# PRE_bsss2      4                  [3, 2, 4, 1]
# PRE_gpse7      4                  [2, 3, 4, 1]
# POST_phqD6     4                  [2, 0, 1, 3]
# PRE_gpse9      4                  [2, 3, 4, 1]
# PRE_gpse10     4                  [3, 4, 2, 1]
# POST_phqD1     4                  [2, 0, 1, 3]
# PRE_bdi21      4                  [2, 0, 3, 1]
# PRE_bdi20      4                  [1, 0, 2, 3]
# PRE_bdi19      4                  [1, 2, 3, 0]
# PRE_bdi18      4                  [1, 0, 3, 2]
# PRE_bdi17      4                  [0, 1, 2, 3]
# PRE_bdi16      4                  [2, 1, 3, 0]
# PRE_bdi15      4                  [1, 2, 3, 0]
# PRE_bdi14      4                  [1, 0, 2, 3]
# PRE_bdi13      4                  [1, 2, 0, 3]
# PRE_bdi12      4                  [1, 0, 2, 3]
# PRE_bdi11      4                  [1, 0, 2, 3]
# PRE_bdi10      4                  [1, 2, 0, 3]
# PRE_bdi8       4                  [1, 0, 2, 3]
# PRE_bdi7       4                  [0, 1, 2, 3]
# PRE_bdi6       4                  [0, 1, 3, 2]
# PRE_bdi5       4                  [0, 1, 2, 3]
# PRE_bdi4       4                  [1, 2, 0, 3]
# PRE_bdi3       4                  [1, 2, 0, 3]
# PRE_bdi2       4                  [1, 0, 2, 3]
# PRE_bdi1       4                  [1, 2, 0, 3]
# PRE_gad1       4                  [2, 1, 3, 0]
# PRE_gad2       4                  [1, 2, 3, 0]
# PRE_gad3       4                  [1, 2, 0, 3]
# PRE_gad4       4                  [1, 0, 2, 3]
# POST_phqD8     4                  [0, 1, 2, 3]
# POST_phqD7     4                  [1, 0, 2, 3]
# PRE_gpse4      4                  [3, 2, 1, 4]
# POST_phqD5     4                  [1, 2, 0, 3]
# POST_phqD4     4                  [2, 1, 3, 0]
# PRE_phqD1      4                  [1, 2, 3, 0]
# PRE_phqD2      4                  [1, 2, 3, 0]
# PRE_phqD3      4                  [2, 1, 3, 0]
# PRE_phqD4      4                  [2, 1, 3, 0]
# PRE_phqD5      4                  [2, 0, 1, 3]
# PRE_phqD6      4                  [1, 2, 3, 0]
# PRE_phqD7      4                  [1, 2, 3, 0]
# POST_phqD3     4                  [1, 0, 2, 3]
# PRE_phqD8      4                  [1, 0, 3, 2]
# PRE_phqD9      4                  [1, 0, 2, 3]
# POST_phqD2     4                  [2, 0, 1, 3]
# PRE_gad7       4                  [1, 0, 2, 3]
# PRE_gad6       4                  [0, 2, 3, 1]
# PRE_gad5       4                  [0, 3, 1, 2]
# PRE_gpse3      4                  [2, 3, 4, 1]
# POST_phqD9     3                  [1, 0, 2]
# PRE_euheals3   3                  [5, 9, 1]
# PRE_euheals2   3                  [5, 9, 1]
# PRE_phqS6      3                  [2, 1, 0]
# PRE_sickleave  3                  [1, 0, 2]
# PRE_phqS10     3                  [0, 1, 2]
# PRE_phqS9      3                  [0, 1, 2]
# PRE_phqS7      3                  [0, 1, 2]
# PRE_phqS8      3                  [0, 2, 1]
# PRE_phqS5      3                  [0, 1, 2]
# PRE_phqS4      3                  [1, 2, 0]
# PRE_phqS3      3                  [2, 0, 1]
# PRE_phqS2      3                  [0, 1, 2]
# PRE_phqS1      3                  [0, 1, 2]
# PRE_euheals1   3                  [5, 9, 1]
# PRE_neurol     2                  [0, 1]
# PRE_therapy    2                  [0, 1]
# PRE_bdi9       2                  [1, 0]
# PRE_counsel    2                  [0, 1]
# PRE_selfhelp   2                  [0, 1]
# PRE_treatment  2                  [1, 0]
# PRE_doc        2                  [1, 0]
# PRE_ill        2                  [1, 0]
# PRE_kPT        2                  [1, 0]
# PRE_support    2                  [1, 0]
# PRE_hospital   2                  [0, 1]
# PRE_med        2                  [1, 0]
# TI_MDE_x       2                  [0, 1]
# PRE_hos_other  2                  [0, 1]
# TI_bip1        2                  [0, 1]
# TI_bip2        2                  [0, 1]
# TI_MDE         2                  [1, 0]
# TI_dyst        2                  [0, 1]
# TI_MDE_vr      2                  [0, 1]
# TI_MDE_tr      2                  [0, 1]
# TI_HYP_vr      2                  [0, 1]
# TI_MAN_vr      2                  [0, 1]
# TI_medik       2                  [0, 1]
# PRE_sex        2                  [0, 1]
# studyVariant   2                  [0, 1]
# coach_gender   2                  [1, 0]

# %% [markdown]
# --> Data types of some scales have to be changed from object to numeric to create sum scores

# %% [markdown]
# ### 1.2.5 Create Sum Scores of clinical screenings

# %% [markdown]
# #### BDI-II

# %%
pre_bdi_columns = ['PRE_bdi1','PRE_bdi2','PRE_bdi3',
               'PRE_bdi4','PRE_bdi5','PRE_bdi6','PRE_bdi7','PRE_bdi8','PRE_bdi9','PRE_bdi10','PRE_bdi11','PRE_bdi12',
               'PRE_bdi13','PRE_bdi14','PRE_bdi15','PRE_bdi16','PRE_bdi17','PRE_bdi18','PRE_bdi19','PRE_bdi20',
               'PRE_bdi21']

# %%
df2["PRE_bdi_sum"] = df2[pre_bdi_columns].sum(axis=1).astype('Int64')

# %%
df2["PRE_bdi_sum"].describe()
# Out:
# count    1278.000000
# mean     21.448357
# std      4.063715
# min      14.000000
# 25%      18.000000
# 50%      22.000000
# 75%      25.000000
# max      28.000000
# Name: PRE_bdi_sum, dtype: float64

# %%
miss_df2 = missing_values_table(df2)
miss_df2
# Out:
# The dataset has 211 columns.
# There are 0 columns that have missing values.
# Empty DataFrame
# Columns: [Missing Values, % of Total Values, Missing Values]
# Index: []

# %% [markdown]
# #### PHQ-D

# %%
pre_phq_columns = ['PRE_phqD1','PRE_phqD2','PRE_phqD3','PRE_phqD4','PRE_phqD5','PRE_phqD6','PRE_phqD7',
               'PRE_phqD8','PRE_phqD9']

# %%
df2[pre_phq_columns] = df2[pre_phq_columns].apply(pd.to_numeric, errors='coerce').astype('Int64')

# %%
df2["phq_d_sum"] = df2[pre_phq_columns].sum(axis=1)

# %%
df2["phq_d_sum"].describe()
# Out:
# count    1278.000000
# mean     11.585290
# std      3.306125
# min      4.000000
# 25%      9.000000
# 50%      11.000000
# 75%      14.000000
# max      23.000000
# Name: phq_d_sum, dtype: float64

# %% [markdown]
#  **PHQ-D Outcome**

# %%
post_phq_columns = ['POST_phqD1', 'POST_phqD2','POST_phqD3','POST_phqD4','POST_phqD5',
               'POST_phqD6','POST_phqD7','POST_phqD8','POST_phqD9']

# %%
df2[post_phq_columns] = df2[post_phq_columns].apply(pd.to_numeric, errors='coerce').astype('Int64')

# %%
df2["phq_post"] = df2[post_phq_columns].sum(axis=1)

# %%
df2["phq_post"].describe()
# Out:
# count    1278.000000
# mean     6.942879
# std      4.224591
# min      0.000000
# 25%      4.000000
# 50%      6.000000
# 75%      9.000000
# max      24.000000
# Name: phq_post, dtype: float64

# %%
df2.drop(post_phq_columns, axis=1, inplace=True)

# %% [markdown]
# #### PHQ-S

# %%
phq_s_columns = ['PRE_phqS1','PRE_phqS2','PRE_phqS3','PRE_phqS4','PRE_phqS5','PRE_phqS6','PRE_phqS7',
               'PRE_phqS8','PRE_phqS9', 'PRE_phqS10']

# %%
df2[phq_s_columns] = df2[phq_s_columns].apply(pd.to_numeric, errors='coerce').astype('Int64')

# %%
df2["phq_s_sum"] = df2[phq_s_columns].sum(axis=1)

# %%
df2["phq_s_sum"].describe()
# Out:
# count    1278.000000
# mean     8.992175
# std      3.294465
# min      0.000000
# 25%      7.000000
# 50%      9.000000
# 75%      11.000000
# max      20.000000
# Name: phq_s_sum, dtype: float64

# %% [markdown]
# #### EUROHIS-QOL

# %%
eurohis_columns = ['PRE_eurohis1','PRE_eurohis2','PRE_eurohis3','PRE_eurohis4','PRE_eurohis5','PRE_eurohis6',
                   'PRE_eurohis7','PRE_eurohis8']

# %%
df2[eurohis_columns] = df2[eurohis_columns].apply(pd.to_numeric, errors='coerce').astype('Int64')

# %%
df2["eurohis_sum"] = df2[eurohis_columns].sum(axis=1)

# %% [markdown]
# #### IMET

# %%
imet_columns = ['PRE_imet1','PRE_imet2','PRE_imet3','PRE_imet4','PRE_imet5','PRE_imet6','PRE_imet7',
                'PRE_imet8','PRE_imet9','PRE_imet10']

# %%
df2[imet_columns] = df2[imet_columns].apply(pd.to_numeric, errors='coerce')

# %%
df2['PRE_imet10']
# Out:
# 1       10
# 3       5
# 4       9
# 5       4
# 6       5
# 8       9
# 9       8
# 10      5
# 11      8
# 13      7
# 14      10
# 15      2
# 16      2
# 17      8
# 18      5
# 19      9
# 20      8
# 21      4
# 22      6
# 23      6
# 24      7
# 25      7
# 26      4
# 29      5
# 30      5
# 31      9
# 32      5
# 33      9
# 34      6
# 37      5
# 38      8
# 40      5
# 41      0
# 43      2
# 44      8
# 47      7
# 48      8
# 50      5
# 51      9
# 52      5
# 53      10
# 55      4
# 58      9
# 59      7
# 60      4
# 61      4
# 63      5
# 64      8
# 65      8
# 67      3
# 68      2
# 69      8
# 70      7
# 73      10
# 75      6
# 76      8
# 77      8
# 78      9
# 79      4
# 81      7
# 82      8
# 84      5
# 85      8
# 86      8
# 87      8
# 89      5
# 90      5
# 91      8
# 92      9
# 93      4
# 94      2
# 95      7
# 96      8
# 97      3
# 99      8
# 101     8
# 102     3
# 103     3
# 104     7
# 106     1
# 108     7
# 109     5
# 110     3
# 111     3
# 112     8
# 113     5
# 114     7
# 115     7
# 116     4
# 118     6
# 119     5
# 120     9
# 121     8
# 124     8
# 125     9
# 126     6
# 127     5
# 128     8
# 130     7
# 131     4
# 132     6
# 133     1
# 138     6
# 141     8
# 142     7
# 143     7
# 144     3
# 147     5
# 149     10
# 151     8
# 152     9
# 153     7
# 155     6
# 156     2
# 157     7
# 159     8
# 161     0
# 162     7
# 163     6
# 164     5
# 166     5
# 167     6
# 169     9
# 170     5
# 171     7
# 173     8
# 174     1
# 175     5
# 176     8
# 178     8
# 179     8
# 181     2
# 182     8
# 183     9
# 185     8
# 187     5
# 188     5
# 189     9
# 190     6
# 191     8
# 192     10
# 194     5
# 196     5
# 197     2
# 198     7
# 199     8
# 200     6
# 201     7
# 202     10
# 203     5
# 204     7
# 206     7
# 207     3
# 209     7
# 210     2
# 211     6
# 212     6
# 214     8
# 215     3
# 217     8
# 219     4
# 220     9
# 221     7
# 222     9
# 223     9
# 225     8
# 226     8
# 227     0
# 230     10
# 231     8
# 233     4
# 234     8
# 235     4
# 238     2
# 239     5
# 240     7
# 242     9
# 243     4
# 246     8
# 247     3
# 248     3
# 249     3
# 251     7
# 253     2
# 254     6
# 255     8
# 257     8
# 258     0
# 260     5
# 261     2
# 262     6
# 264     10
# 266     6
# 268     8
# 270     8
# 271     7
# 272     7
# 273     4
# 274     3
# 276     7
# 277     5
# 278     0
# 279     1
# 280     5
# 281     8
# 282     3
# 284     7
# 285     3
# 287     3
# 288     9
# 289     8
# 290     5
# 291     5
# 293     7
# 294     10
# 295     2
# 296     8
# 298     6
# 300     9
# 301     7
# 302     5
# 303     9
# 304     0
# 305     5
# 306     9
# 307     10
# 308     2
# 309     10
# 310     4
# 312     3
# 314     6
# 315     9
# 316     5
# 317     7
# 319     6
# 323     5
# 326     10
# 328     7
# 329     7
# 332     6
# 334     7
# 335     7
# 336     8
# 337     5
# 338     8
# 340     7
# 341     5
# 342     7
# 343     0
# 344     3
# 345     0
# 347     8
# 349     6
# 350     5
# 351     5
# 352     7
# 353     8
# 354     5
# 355     5
# 357     4
# 359     8
# 360     9
# 362     7
# 363     6
# 364     7
# 365     8
# 366     4
# 367     4
# 368     9
# 369     7
# 370     4
# 371     8
# 372     1
# 373     2
# 374     3
# 375     3
# 376     5
# 377     7
# 378     3
# 379     6
# 380     4
# 381     7
# 383     8
# 384     5
# 385     3
# 386     6
# 387     1
# 388     8
# 389     8
# 391     8
# 392     7
# 393     1
# 394     8
# 395     5
# 397     10
# 398     5
# 401     8
# 402     2
# 403     8
# 404     3
# 405     3
# 406     9
# 407     3
# 408     6
# 409     4
# 410     7
# 411     7
# 413     5
# 414     8
# 416     8
# 417     6
# 418     5
# 419     5
# 420     9
# 421     5
# 422     8
# 423     3
# 424     7
# 428     7
# 429     6
# 431     2
# 432     6
# 434     5
# 435     3
# 436     6
# 438     1
# 439     4
# 440     5
# 441     7
# 442     8
# 443     10
# 444     8
# 445     2
# 446     5
# 447     7
# 448     3
# 450     8
# 451     7
# 453     6
# 454     8
# 455     2
# 456     7
# 459     3
# 460     6
# 461     4
# 462     1
# 464     10
# 465     7
# 467     4
# 469     8
# 470     6
# 471     8
# 472     2
# 473     9
# 474     9
# 475     1
# 476     5
# 478     6
# 479     7
# 480     4
# 481     9
# 483     6
# 485     8
# 486     9
# 487     6
# 488     8
# 489     6
# 491     8
# 492     3
# 493     7
# 494     6
# 495     8
# 496     6
# 497     7
# 498     7
# 500     8
# 501     7
# 502     9
# 503     10
# 505     3
# 506     8
# 507     1
# 509     6
# 510     2
# 511     8
# 512     8
# 515     5
# 517     3
# 518     7
# 519     6
# 520     9
# 521     10
# 522     6
# 523     10
# 524     4
# 526     9
# 529     7
# 530     6
# 534     10
# 536     8
# 537     5
# 539     6
# 540     5
# 541     9
# 542     9
# 543     1
# 544     8
# 545     7
# 546     3
# 547     8
# 548     3
# 549     9
# 553     6
# 554     5
# 556     8
# 557     8
# 559     7
# 560     5
# 562     8
# 563     2
# 564     5
# 565     0
# 566     7
# 567     8
# 570     6
# 572     7
# 573     8
# 574     2
# 575     9
# 576     9
# 579     9
# 581     10
# 582     8
# 583     4
# 585     8
# 587     0
# 588     7
# 589     9
# 590     8
# 591     9
# 593     9
# 595     5
# 596     5
# 597     4
# 598     9
# 599     9
# 601     7
# 602     9
# 603     5
# 605     0
# 606     8
# 607     1
# 608     1
# 609     9
# 610     6
# 611     3
# 613     6
# 615     8
# 617     10
# 618     6
# 619     0
# 620     7
# 622     8
# 623     8
# 625     7
# 626     3
# 627     6
# 628     5
# 629     3
# 630     7
# 633     7
# 635     5
# 637     7
# 638     8
# 640     9
# 642     7
# 643     7
# 644     4
# 645     5
# 646     8
# 647     8
# 649     3
# 653     8
# 654     5
# 655     10
# 656     8
# 658     2
# 659     8
# 660     4
# 661     5
# 663     5
# 664     8
# 665     5
# 666     5
# 667     7
# 668     5
# 670     8
# 673     8
# 675     7
# 676     7
# 677     7
# 678     8
# 679     2
# 680     5
# 681     8
# 682     6
# 683     5
# 684     4
# 688     4
# 689     6
# 690     9
# 691     8
# 692     5
# 693     5
# 694     6
# 695     7
# 696     3
# 697     9
# 698     10
# 699     7
# 701     1
# 702     10
# 704     9
# 707     5
# 708     6
# 709     9
# 712     8
# 713     5
# 715     4
# 723     8
# 725     3
# 726     7
# 727     10
# 728     8
# 730     10
# 731     7
# 734     7
# 737     5
# 738     5
# 740     4
# 741     8
# 742     4
# 744     1
# 745     4
# 746     7
# 747     8
# 751     7
# 752     5
# 753     10
# 755     10
# 756     8
# 763     5
# 764     8
# 765     7
# 766     9
# 768     7
# 769     8
# 771     8
# 774     8
# 775     4
# 776     9
# 778     9
# 779     6
# 780     8
# 781     4
# 786     5
# 787     8
# 790     1
# 791     3
# 792     8
# 794     10
# 795     4
# 796     7
# 797     8
# 798     7
# 799     7
# 800     7
# 801     7
# 802     9
# 803     8
# 804     8
# 805     2
# 807     6
# 808     4
# 809     9
# 811     5
# 812     0
# 813     1
# 814     8
# 816     9
# 817     5
# 818     4
# 820     4
# 821     6
# 823     9
# 824     9
# 825     6
# 826     5
# 828     10
# 829     8
# 830     7
# 831     2
# 832     5
# 836     9
# 837     7
# 838     6
# 839     10
# 840     7
# 841     9
# 842     7
# 843     6
# 844     7
# 845     8
# 846     7
# 849     7
# 850     8
# 852     0
# 853     10
# 854     6
# 855     6
# 857     3
# 858     5
# 860     3
# 862     7
# 865     5
# 866     10
# 867     9
# 868     5
# 869     4
# 870     5
# 871     3
# 873     6
# 874     10
# 875     10
# 876     7
# 877     3
# 878     10
# 879     4
# 880     5
# 881     4
# 883     3
# 884     9
# 885     6
# 886     4
# 887     0
# 888     6
# 889     10
# 890     2
# 891     8
# 892     2
# 894     9
# 895     7
# 896     10
# 898     7
# 899     4
# 900     4
# 901     5
# 902     9
# 904     8
# 905     8
# 907     7
# 909     8
# 910     6
# 911     6
# 912     6
# 914     7
# 915     9
# 916     9
# 917     9
# 918     7
# 920     8
# 921     7
# 922     7
# 923     7
# 925     8
# 926     9
# 927     9
# 929     6
# 930     8
# 931     5
# 932     4
# 933     3
# 934     5
# 936     6
# 937     10
# 938     2
# 940     8
# 941     7
# 942     6
# 944     2
# 945     1
# 946     10
# 947     3
# 948     6
# 950     2
# 951     4
# 953     5
# 954     4
# 955     7
# 956     5
# 957     9
# 960     4
# 961     10
# 962     4
# 963     8
# 964     8
# 965     8
# 966     6
# 970     8
# 971     8
# 972     3
# 973     10
# 976     7
# 977     4
# 978     8
# 980     8
# 982     7
# 983     8
# 984     3
# 985     5
# 986     3
# 989     7
# 990     4
# 991     2
# 992     8
# 993     6
# 995     8
# 996     5
# 997     9
# 998     7
# 999     8
# 1001    6
# 1002    8
# 1003    2
# 1004    10
# 1005    9
# 1006    8
# 1009    5
# 1010    7
# 1011    3
# 1012    7
# 1013    4
# 1015    7
# 1016    9
# 1017    4
# 1018    8
# 1019    3
# 1022    2
# 1023    10
# 1024    5
# 1025    8
# 1026    4
# 1027    5
# 1028    7
# 1029    9
# 1030    3
# 1031    3
# 1032    7
# 1033    4
# 1034    6
# 1035    6
# 1036    9
# 1039    2
# 1041    7
# 1043    10
# 1044    8
# 1045    8
# 1046    10
# 1047    5
# 1048    2
# 1049    6
# 1050    6
# 1051    0
# 1052    8
# 1053    8
# 1054    8
# 1055    7
# 1056    3
# 1061    7
# 1062    6
# 1063    6
# 1064    5
# 1065    3
# 1067    5
# 1069    10
# 1070    8
# 1073    9
# 1075    0
# 1079    10
# 1080    4
# 1082    7
# 1083    9
# 1084    5
# 1085    5
# 1086    5
# 1088    5
# 1089    7
# 1091    2
# 1092    4
# 1093    5
# 1094    8
# 1095    9
# 1096    8
# 1097    3
# 1099    7
# 1100    7
# 1101    3
# 1102    4
# 1103    8
# 1104    4
# 1107    9
# 1108    7
# 1109    8
# 1110    4
# 1111    7
# 1112    8
# 1113    8
# 1114    6
# 1115    8
# 1118    8
# 1119    8
# 1120    4
# 1121    7
# 1124    6
# 1125    6
# 1126    4
# 1127    7
# 1128    5
# 1129    5
# 1130    6
# 1131    8
# 1132    4
# 1133    4
# 1135    8
# 1136    9
# 1137    6
# 1138    4
# 1139    6
# 1140    9
# 1141    6
# 1144    4
# 1145    4
# 1148    7
# 1149    7
# 1150    1
# 1151    3
# 1153    9
# 1155    3
# 1156    8
# 1158    9
# 1160    5
# 1161    4
# 1163    1
# 1164    7
# 1166    8
# 1168    8
# 1170    4
# 1171    10
# 1173    6
# 1175    5
# 1177    6
# 1178    7
# 1180    6
# 1181    5
# 1182    5
# 1184    7
# 1185    9
# 1186    7
# 1187    3
# 1188    6
# 1191    5
# 1192    8
# 1193    0
# 1194    5
# 1196    10
# 1199    9
# 1200    8
# 1201    4
# 1202    9
# 1203    3
# 1204    4
# 1205    0
# 1206    5
# 1207    7
# 1208    6
# 1209    7
# 1210    5
# 1211    10
# 1212    6
# 1213    4
# 1214    8
# 1215    6
# 1216    9
# 1217    5
# 1218    8
# 1219    6
# 1221    8
# 1222    4
# 1224    8
# 1226    2
# 1228    6
# 1230    8
# 1231    8
# 1233    10
# 1234    8
# 1235    5
# 1236    4
# 1237    8
# 1238    7
# 1239    7
# 1240    2
# 1241    8
# 1242    8
# 1243    0
# 1244    3
# 1245    7
# 1247    7
# 1248    8
# 1249    6
# 1250    7
# 1253    4
# 1254    10
# 1255    3
# 1256    8
# 1257    7
# 1258    7
# 1259    8
# 1260    8
# 1261    4
# 1262    6
# 1263    8
# 1264    7
# 1267    8
# 1268    5
# 1269    8
# 1271    6
# 1272    4
# 1273    7
# 1274    6
# 1275    6
# 1276    9
# 1277    5
# 1278    3
# 1279    5
# 1280    10
# 1284    5
# 1285    8
# 1286    5
# 1287    7
# 1288    5
# 1289    7
# 1290    2
# 1291    7
# 1292    7
# 1293    4
# 1294    3
# 1295    10
# 1296    8
# 1297    9
# 1298    5
# 1299    7
# 1300    4
# 1301    7
# 1303    7
# 1304    5
# 1308    2
# 1309    7
# 1312    0
# 1313    6
# 1314    3
# 1315    9
# 1316    8
# 1319    1
# 1320    4
# 1321    5
# 1322    8
# 1324    3
# 1326    0
# 1327    5
# 1328    4
# 1329    2
# 1330    6
# 1331    0
# 1332    9
# 1333    5
# 1334    8
# 1335    4
# 1336    2
# 1337    8
# 1338    4
# 1339    6
# 1340    3
# 1342    0
# 1343    7
# 1344    6
# 1346    10
# 1347    9
# 1348    10
# 1349    7
# 1350    10
# 1352    3
# 1353    7
# 1354    7
# 1356    5
# 1358    8
# 1359    0
# 1361    7
# 1362    3
# 1364    9
# 1366    3
# 1367    5
# 1368    8
# 1370    3
# 1371    9
# 1372    5
# 1375    6
# 1376    5
# 1377    2
# 1379    5
# 1382    5
# 1383    2
# 1384    8
# 1385    7
# 1386    6
# 1387    8
# 1388    8
# 1389    8
# 1390    7
# 1392    8
# 1393    3
# 1395    9
# 1396    7
# 1399    4
# 1401    6
# 1403    6
# 1404    5
# 1405    8
# 1406    10
# 1407    3
# 1408    5
# 1409    5
# 1410    3
# 1412    9
# 1413    1
# 1414    8
# 1416    6
# 1418    5
# 1419    7
# 1421    5
# 1422    3
# 1423    7
# 1424    6
# 1425    7
# 1426    3
# 1427    5
# 1428    6
# 1434    8
# 1435    5
# 1436    5
# 1437    8
# 1438    7
# 1439    0
# 1440    5
# 1441    6
# 1442    10
# 1443    5
# 1445    10
# 1446    8
# 1448    5
# 1449    5
# 1450    7
# 1451    6
# 1453    5
# 1454    5
# 1455    5
# 1456    8
# 1457    7
# 1458    5
# 1459    8
# 1460    5
# 1462    5
# 1463    1
# 1465    2
# 1466    10
# 1467    2
# 1468    8
# 1470    5
# 1471    7
# 1473    8
# 1475    2
# 1477    7
# 1478    9
# 1479    8
# 1480    4
# 1482    9
# 1484    7
# 1485    8
# 1487    7
# 1488    4
# 1492    8
# 1493    5
# 1494    8
# 1496    1
# 1498    6
# 1500    9
# 1501    8
# 1502    6
# 1503    3
# 1504    2
# 1505    3
# 1506    8
# 1508    7
# 1509    7
# 1511    9
# 1513    8
# 1515    9
# 1516    8
# 1519    6
# 1520    8
# 1524    7
# 1526    2
# 1527    7
# 1530    8
# 1531    9
# 1532    9
# 1534    4
# 1535    7
# 1536    5
# 1537    4
# 1538    4
# 1540    9
# 1541    6
# 1544    5
# 1547    6
# 1548    8
# 1549    5
# 1552    6
# 1553    2
# 1554    10
# 1555    9
# 1556    1
# 1559    4
# 1561    3
# 1565    10
# 1569    6
# 1570    5
# 1571    8
# 1574    8
# 1576    7
# 1577    8
# 1578    5
# 1579    5
# 1583    2
# 1585    7
# 1586    5
# 1587    3
# 1588    3
# 1589    6
# 1592    3
# 1593    9
# 1594    3
# 1596    7
# 1599    9
# 1600    9
# 1603    9
# 1604    9
# 1607    8
# 1612    5
# 1613    8
# 1614    1
# 1615    7
# 1617    10
# 1619    5
# 1620    8
# 1622    8
# 1623    9
# 1627    6
# 1628    5
# 1630    5
# 1631    5
# 1633    5
# 1635    8
# 1636    3
# 1639    8
# 1640    7
# 1641    7
# 1642    10
# 1644    7
# 1645    5
# 1646    6
# 1647    5
# 1648    7
# 1649    6
# 1650    2
# 1651    7
# 1653    0
# 1654    6
# 1656    6
# 1657    8
# 1658    9
# 1659    9
# 1660    3
# 1661    6
# 1662    5
# 1667    8
# 1670    4
# 1673    9
# 1674    8
# 1675    7
# 1677    3
# 1678    8
# 1681    7
# 1682    0
# 1684    2
# 1685    8
# 1686    2
# 1687    7
# 1688    8
# 1689    4
# 1690    7
# 1691    9
# 1694    6
# 1698    9
# 1700    3
# 1701    5
# 1703    2
# 1704    6
# 1705    8
# 1706    7
# 1707    7
# 1709    7
# 1710    8
# 1711    3
# 1712    5
# 1714    8
# 1715    7
# 1717    9
# 1718    10
# 1719    7
# 1722    8
# 1723    6
# 1724    8
# 1725    10
# 1727    7
# 1728    1
# 1729    5
# 1730    7
# 1731    8
# 1732    1
# 1733    5
# 1734    8
# 1735    7
# 1736    8
# 1741    2
# 1742    9
# 1744    5
# 1746    7
# 1747    5
# 1748    3
# 1751    5
# 1752    4
# 1753    7
# 1754    5
# 1757    7
# 1758    10
# 1760    8
# 1761    7
# 1762    9
# 1763    8
# 1764    4
# 1765    9
# 1766    3
# 1767    8
# 1770    8
# 1772    8
# 1773    4
# 1775    3
# 1776    8
# Name: PRE_imet10, dtype: Int64

# %%
df2['PRE_imet10'] = df2['PRE_imet10'].map({0:10, 1:9, 2:8, 3:7, 4:6, 5:5, 6:4, 7:3, 8:2, 9:1, 10:0})

# %%
df2["imet_sum"] = df2[imet_columns].sum(axis=1)

# %%
df2["imet_sum"].describe()
# Out:
# count    1278.000000
# mean     39.640063
# std      13.790082
# min      3.000000
# 25%      30.000000
# 50%      38.000000
# 75%      49.000000
# max      88.000000
# Name: imet_sum, dtype: float64

# %% [markdown]
# #### GAD7

# %%
gad_columns= ['PRE_gad1','PRE_gad2','PRE_gad3','PRE_gad4','PRE_gad5','PRE_gad6','PRE_gad7']

# %%
df2[gad_columns] = df2[gad_columns].apply(pd.to_numeric, errors='coerce').astype('Int64')

# %%
df2["gad_sum"] = df2[gad_columns].sum(axis=1)

# %%
df2.gad_sum.describe()
# Out:
# count    1278.000000
# mean     9.797340
# std      3.674982
# min      0.000000
# 25%      7.000000
# 50%      9.000000
# 75%      12.000000
# max      21.000000
# Name: gad_sum, dtype: float64

# %% [markdown]
# **Costa**

# %% [markdown]
# Summenscore, keine invertierten Items. Nach Subskalen erkundigen

# %%
costa_columns = ['PRE_costa1', 'PRE_costa2', 'PRE_costa3','PRE_costa4', 'PRE_costa5', 'PRE_costa6', 'PRE_costa7', 
                 'PRE_costa8', 'PRE_costa9', 'PRE_costa10', 'PRE_costa11','PRE_costa12', 'PRE_costa13', 'PRE_costa14',
                 'PRE_costa15', 'PRE_costa16', 'PRE_costa17', 'PRE_costa18','PRE_costa19', 'PRE_costa20', 'PRE_costa21']

# %%
df2[costa_columns] = df2[costa_columns].apply(pd.to_numeric, errors='coerce').astype('Int64')

# %%
df2["costa_sum"] = df2[costa_columns].sum(axis=1).astype('Int64')

# %%
df2.costa_sum.describe()
# Out:
# count    1278.000000
# mean     51.119718
# std      17.548293
# min      0.000000
# 25%      39.250000
# 50%      52.000000
# 75%      64.000000
# max      99.000000
# Name: costa_sum, dtype: float64

# %% [markdown]
# **Pathev**

# %% [markdown]
# Therapieerwartung und Therapieevaluation. 1,3,5,7,9,10 sind negativ (invertiert).

# %%
pathev_columns = ['PRE_pathev1', 'PRE_pathev2', 'PRE_pathev3', 'PRE_pathev4','PRE_pathev5', 'PRE_pathev6', 
                  'PRE_pathev7', 'PRE_pathev8', 'PRE_pathev9', 'PRE_pathev10']

# %%
df2[pathev_columns] = df2[pathev_columns].apply(pd.to_numeric, errors='coerce').astype('Int64')

# %%
invert_columns = ['PRE_pathev1', 'PRE_pathev3','PRE_pathev5','PRE_pathev7','PRE_pathev9', 'PRE_pathev10']

# %%
for column in invert_columns:
    df2[column] = df2[column].map({1:5, 2:4, 3:3, 4:2, 5:1})

# %%
df2["pathev_sum"] = df2[pathev_columns].sum(axis=1).astype('Int64')

# %%
df2["pathev_sum"].describe()
# Out:
# count    1278.000000
# mean     36.738654
# std      5.219738
# min      19.000000
# 25%      33.000000
# 50%      37.000000
# 75%      40.000000
# max      50.000000
# Name: pathev_sum, dtype: float64

# %% [markdown]
# **Euheals**

# %% [markdown]
# Summenscore. Keine invertierten Items

# %%
euheals_columns = ['PRE_euheals1','PRE_euheals2','PRE_euheals3']

# %%
df2[euheals_columns] = df2[euheals_columns].apply(pd.to_numeric, errors='coerce').astype('Int64')

# %%
df2["euheals_sum"] = df2[euheals_columns].sum(axis=1).astype('Int64')

# %%
df2["euheals_sum"].describe()
# Out:
# count    1278.000000
# mean     20.899844
# std      4.651284
# min      3.000000
# 25%      19.000000
# 50%      19.000000
# 75%      27.000000
# max      27.000000
# Name: euheals_sum, dtype: float64

# %% [markdown]
# **IPQ-R**

# %% [markdown]
# Krankheitswahrnehmung. Item 8 ist invertiert. Auswertung = Summenscore

# %%
ipqr_columns = ['PRE_ipqr1','PRE_ipqr2','PRE_ipqr3','PRE_ipqr4','PRE_ipqr5',
               'PRE_ipqr6','PRE_ipqr7','PRE_ipqr8','PRE_ipqr9','PRE_ipqr10','PRE_ipqr11','PRE_ipqr12','PRE_ipqr13',
               'PRE_ipqr14','PRE_ipqr15','PRE_ipqr16','PRE_ipqr17','PRE_ipqr18']

# %%
df2[ipqr_columns] = df2[ipqr_columns].apply(pd.to_numeric, errors='coerce')

# %%
df2['PRE_ipqr8'] = df2['PRE_ipqr8'].map({1:5, 2:4, 3:3, 4:2, 5:1})

# %%
df2["ipqr_sum"] = df2[ipqr_columns].sum(axis=1).astype('Int64')

# %%
df2["ipqr_sum"].describe()
# Out:
# count    1278.000000
# mean     55.755869
# std      7.290903
# min      30.000000
# 25%      51.000000
# 50%      56.000000
# 75%      60.750000
# max      80.000000
# Name: ipqr_sum, dtype: float64

# %% [markdown]
# **GPSE**

# %% [markdown]
# Selbstwirksamkeitserwartung. Nur eine Skala --> Summenwert

# %%
gpse_columns = ['PRE_gpse1','PRE_gpse2','PRE_gpse3','PRE_gpse4','PRE_gpse5','PRE_gpse6',
               'PRE_gpse7','PRE_gpse8','PRE_gpse9','PRE_gpse10']

# %%
df2[gpse_columns] = df2[gpse_columns].apply(pd.to_numeric, errors='coerce')

# %%
df2["gpse_sum"] = df2[gpse_columns].sum(axis=1).astype('Int64')

# %%
df2["gpse_sum"].describe()
# Out:
# count    1278.000000
# mean     24.399844
# std      4.756949
# min      10.000000
# 25%      21.000000
# 50%      25.000000
# 75%      28.000000
# max      40.000000
# Name: gpse_sum, dtype: float64

# %% [markdown]
# **BSSS**
#
# Berliner Social Support Skalen. 2 Subskalen: Perceived Support (Item 1-8), Support Seeking (Item 9-13)

# %%
bsss_columns = ['PRE_bsss1','PRE_bsss2','PRE_bsss3','PRE_bsss4','PRE_bsss5','PRE_bsss6','PRE_bsss7','PRE_bsss8',
                'PRE_bsss9','PRE_bsss10','PRE_bsss11','PRE_bsss12','PRE_bsss13']

# %%
df2[bsss_columns] = df2[bsss_columns].apply(pd.to_numeric, errors='coerce').astype('Int64')

# %%
df2["bsss_perceived"] = df2[['PRE_bsss1','PRE_bsss2','PRE_bsss3','PRE_bsss4','PRE_bsss5','PRE_bsss6','PRE_bsss7',
                           'PRE_bsss8']].sum(axis=1).astype('Int64')

# %%
df2["bsss_suppseek"] = df2[['PRE_bsss9','PRE_bsss10','PRE_bsss11','PRE_bsss12','PRE_bsss13']].sum(axis=1).astype('Int64')

# %% [markdown]
# **PVQ**
#
# Subskalen: Selbstbestimmung (Item 1,11), Macht (Item 2,17), Universalismus (Item 3,8,19), Leistung (Item 4,13), Sicherheit (Item 5,14), Stimulation (Item 6,15), Konformität (Item 7,16), Tradition (Item 9, 20), Hedonismus (Item 10,21), Benevolenz (Item 12,18) --> Summenscores machen wenig Sinn

# %%
pvq_columns = ['PRE_pvq1','PRE_pvq2','PRE_pvq3','PRE_pvq4','PRE_pvq5','PRE_pvq6','PRE_pvq7','PRE_pvq8','PRE_pvq9',
               'PRE_pvq10','PRE_pvq11','PRE_pvq12','PRE_pvq13','PRE_pvq14','PRE_pvq15','PRE_pvq16','PRE_pvq17',
               'PRE_pvq18','PRE_pvq19','PRE_pvq20','PRE_pvq21']

# %%
df2[pvq_columns] = df2[pvq_columns].apply(pd.to_numeric, errors ='coerce').astype('Int64')

# %%
df2["pvq_self"] = df2[['PRE_pvq1', 'PRE_pvq11']].sum(axis=1).astype('Int64')

# %%
df2["pvq_power"] = df2[['PRE_pvq2', 'PRE_pvq17']].sum(axis=1).astype('Int64')

# %%
df2["pvq_uni"] = df2[['PRE_pvq3', 'PRE_pvq8', 'PRE_pvq19']].sum(axis=1).astype('Int64')

# %%
df2["pvq_achiev"] = df2[['PRE_pvq4','PRE_pvq13']].sum(axis=1).astype('Int64')

# %%
df2["pvq_sec"] = df2[['PRE_pvq5','PRE_pvq14']].sum(axis=1).astype('Int64')

# %%
df2["pvq_stim"] = df2[['PRE_pvq6','PRE_pvq15']].sum(axis=1).astype('Int64')

# %%
df2["pvq_konform"] = df2[['PRE_pvq7','PRE_pvq16']].sum(axis=1).astype('Int64')

# %%
df2["pvq_tradi"] = df2[['PRE_pvq9','PRE_pvq20']].sum(axis=1).astype('Int64')

# %%
df2["pvq_hedo"] = df2[['PRE_pvq10','PRE_pvq21']].sum(axis=1).astype('Int64')

# %%
df2["pvq_benev"] = df2[['PRE_pvq12','PRE_pvq18']].sum(axis=1).astype('Int64')

# %%
#df2.drop(pvq_columns, axis=1, inplace=True)

# %% [markdown]
# ### 1.2.6 Change birthyear to age, registration date to registration year and month to a cyclical feature

# %%
df2["registration_dt"] = pd.to_datetime(df2["registration"])

# %%
df2["age"] = df2["registration_dt"].dt.year - df2['PRE_birth']

# %%
df2["registratrion_month"] = df2["registration_dt"].dt.month

# %%
df2["month_sin"] = np.sin((df2["registratrion_month"]-1)*(2.*np.pi/12))

# %%
df2["month_cos"] = np.cos((df2["registratrion_month"]-1)*(2.*np.pi/12))

# %%
df2["registration"] = df2["registration_dt"].dt.year

# %%
df2.drop(["registration_dt", "registratrion_month", "PRE_birth"], axis=1, inplace= True)

# %% [markdown]
# ### 1.2.6 Create BMI-score from height and weight columns

# %%
df2['PRE_height'] = df2['PRE_height']/100

# %%
df2["bmi_score"] = df2['PRE_weight']/ (df2['PRE_height']*df2['PRE_height'])

# %%
df2.drop(['PRE_weight', 'PRE_height'], axis=1, inplace=True)

# %% [markdown]
# ### 1.2.7 Dummy Categorize TI_rekrut, PRE_work, PRE_household, PRE_residence, Coach, registration

# %%
encoders_list = ["TI_rekrut", "PRE_work", "PRE_household", "PRE_residence", "coach", "registration"]

# %%
df2 = pd.get_dummies(df2, columns=encoders_list)

# %% [markdown]
# ### 1.2.8 Create RCI Variable for BDI as outcome

# %%
df2["phq_change"] = df2["phq_d_sum"] - df2["phq_post"]

# %%
df2["phq_change"] = df2["phq_change"].apply(lambda x:1 if x >= 5 else 0)

# %%
plt.figure(figsize=(10,5)) # Größe der Graphik festlegen
sns.countplot('phq_change',data = df2, palette="deep") # Welche Daten? Welche Farbpalette?
plt.title("Reliable Change on PHQ",fontsize=20,fontweight="bold") 
plt.show()

# %%
df2.drop(["phq_post"], axis=1, inplace=True)

# %% [markdown]
# ### 1.2.9 Prepare missing values for RF Skript

# %%
#miss_df2 = missing_values_table(df2)

# %%
#df2.columns.tolist()

# %%
#missing_cols = list(miss_df2.index)

# %% [markdown]
# ### 1.3 Export pepared data for RF Skript

# %%
filename = path + "prepared_data.csv"

# %%
df2.to_csv(filename, sep=";", encoding="utf-8")

# %%
y = df2["phq_change"]

# %%
X = df2.drop("phq_change", axis=1)

# %% [markdown]
# ## 2.0 Build Random Forest Model

# %% [markdown]
# Best practise for Training Random Forests:
# * Factor out linear relationships between predictor and response (strong linear relationships often overpowers subtler effects) --> change target variable (ggf. anderes Outcome). Andere Idee: erstmal linear Regression, dann Random Forest on Residuals
#     * wichtig: R^2 can be misleading, when comparing models with linear components vs. nonlinear
# * Feature Engineering is key:
#     * use domain knowledge as a guide
#     * explicitly define interaction effects as new predictors (wenn man bereits davon ausgeht, dass es welche gibt)
#     * use multiple metrics that are proxies for the same concept as predictors (leads to better performance, can help make the model less vulnerable to outliers)
# * Best Practices for Interpreting Random Forests:
#     * Check that feature importances align with expectations/intuition
#     * confirm which features are actually adding predictive value
#     * if features expected to be important are not --> data or model issues
# * Check directional relationship between top predictors and response
#     * Manually step through 4-5 levels of a few trees to detect patterns
#     * "Stress Test" the model with syn thetic data, that varies the value of one predictor while holding the others equal
# * Visualize Random Forests with scikit-learn

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.33, stratify = df2["phq_change"], random_state= 42)

# %% [markdown]
# ### Scale BMI Score

# %%
from sklearn.preprocessing import StandardScaler
bmi_scaler = StandardScaler()

# %%
X_train["bmi_score"] = bmi_scaler.fit_transform(X_train[["bmi_score"]])

# %%
X_test["bmi_score"] = bmi_scaler.transform(X_test[["bmi_score"]])

# %% [markdown]
# ### Scale Age

# %%
age_scaler = StandardScaler()

# %%
X_train["age"] = age_scaler.fit_transform(X_train[["age"]])

# %%
X_test["age"] = age_scaler.transform(X_test[["age"]])

# %% [markdown]
# ### Scale PRE Internet

# %%
internet_scaler = StandardScaler()

# %%
X_train["PRE_internet"] = internet_scaler.fit_transform(X_train[["PRE_internet"]])

# %%
X_test["PRE_internet"] = internet_scaler.transform(X_test[["PRE_internet"]])

# %% [markdown]
# ### 2.1 Training Set

# %%
y_train = np.array(y_train)

# %%
feature_names = list(X.columns)

# %%
X_train = np.array(X_train)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
#rf = RandomForestClassifier(n_estimators = 1000, random_state = 42, oob_score=True, class_weight='balanced')

# %%
#rf.fit(X_train, y_train)

# %%
from sklearn.feature_selection import RFE

# %%
rf = RandomForestClassifier(n_estimators=1000, random_state = 42, oob_score=True, class_weight='balanced', max_depth = 7)
#rfe = RFE(estimator=rf, n_features_to_select=100)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=7, n_estimators=1000,
#                        oob_score=True, random_state=42)

# %%
y_pred = rf.predict(X_test)
y_pred_train = rf.predict(X_train)

# %%
accuracy = accuracy_score(y_train, y_pred_train)
print("Train Accuracy: {}".format(accuracy))

print("\nOOB Score: {}".format(rf.oob_score_))

# Nun sagen wir unseren Testdatensatz mithilfe des Test Datensatzes vorher. 
# Dieser wurde von unserem Modell noch nie gesehen. 
    
rf_accuracy = accuracy_score(y_test, y_pred)
print("\nTest Accuracy: {}".format(rf_accuracy))

rf_balanced_accuracy = balanced_accuracy_score(y_test, y_pred)
print("\nBalanced Accuracy: {}".format(rf_balanced_accuracy))

rf_precision = precision_score(y_test, y_pred)
print("\nPrecision: {}".format(rf_precision))

rf_recall = recall_score(y_test, y_pred)
print("\nRecall: {}".format(rf_recall))
# Out:
# Train Accuracy: 0.9836448598130841
#
# OOB Score: 0.616822429906542
#
# Test Accuracy: 0.6563981042654028
#
# Balanced Accuracy: 0.6561397595775755
#
# Precision: 0.6605504587155964
#
# Recall: 0.6697674418604651

# %%
rep = classification_report(y_test, y_pred)

# %%
print(rep)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.65      0.64      0.65       207
#            1       0.66      0.67      0.67       215
#
#     accuracy                           0.66       422
#    macro avg       0.66      0.66      0.66       422
# weighted avg       0.66      0.66      0.66       422

# %%
# Plot Confusion Matrix 
fig, ax = plt.subplots(figsize=(10, 10))

confusion_matrix(y_pred, y_test)
metrics.plot_confusion_matrix(rf, X_test, y_test, normalize=None, ax=ax)

# %%
# Erstelle einen Dataframe mit True und Predicted Values und der errechneten Wahrscheinlichkeit  

probabilities = rf.predict_proba(X_test)

rf_df = pd.DataFrame(zip(y_test, y_pred, probabilities), 
                   columns = ["Actual Value", "Predicted Value", "Probability (left: No, right: Yes)"])

rf_df["Result"] = np.where(rf_df["Actual Value"] == rf_df["Predicted Value"], "Right", "Wrong")


rf_df.set_index("Actual Value").head(20)
# Out:
#               Predicted Value         Probability (left: No, right: Yes)  \
# Actual Value
# 1             0                [0.5539808644672841, 0.44601913553271577]
# 1             0                [0.5130583289979859, 0.48694167100201424]
# 0             0                [0.5938752336159062, 0.4061247663840931]
# 1             1                [0.3705552452758702, 0.6294447547241302]
# 1             1                [0.4456918446841247, 0.5543081553158755]
# 1             1                [0.28741328997553056, 0.7125867100244705]
# 0             0                [0.6506611247776225, 0.34933887522237717]
# 0             0                [0.5357426799952731, 0.4642573200047267]
# 1             1                [0.335778740702734, 0.6642212592972669]
# 0             0                [0.5778755206374311, 0.42212447936256864]
# 0             0                [0.5623779340147441, 0.43762206598525516]
# 0             1                [0.4306186271341391, 0.5693813728658614]
# 1             1                [0.3054845606380975, 0.6945154393619029]
# 1             1                [0.38805656283551004, 0.6119434371644907]
# 1             1                [0.3740910205101025, 0.6259089794898984]
# 1             1                [0.4206091518969228, 0.5793908481030776]
# 0             1                [0.4339497489984525, 0.5660502510015482]
# 0             1                [0.4557500362417173, 0.5442499637582828]
# 0             0                [0.5677566834862542, 0.43224331651374526]
# 0             0                [0.5439744002931474, 0.45602559970685236]
#
#              Result
# Actual Value
# 1             Wrong
# 1             Wrong
# 0             Right
# 1             Right
# 1             Right
# 1             Right
# 0             Right
# 0             Right
# 1             Right
# 0             Right
# 0             Right
# 0             Wrong
# 1             Right
# 1             Right
# 1             Right
# 1             Right
# 0             Wrong
# 0             Wrong
# 0             Right
# 0             Right

# %% [markdown]
# ### Check feature importance

# %%
importances = rf.feature_importances_

# %%
indices = np.argsort(importances)[::-1]

# %%
names = [feature_names[i] for i in indices]

# %%
plt.figure(figsize=(15,5))
plt.title("Feature Importance")
plt.bar(range(X_train.shape[1])[:20], importances[indices][:20])
plt.xticks(range(20), names, rotation=90)
plt.show()
